# %%
from lxml import etree
from bs4 import BeautifulSoup
from polyglot.text import Text
import re
import pandas as pd
import googlemaps
from geopy import distance as dis
import itertools
from sklearn.feature_extraction.text import CountVectorizer
import requests
import pickle
pd.options.display.max_rows = 4000
import numpy as np

# %%
def calculate_distance(p1,p2):
    return dis.distance(p1,p2).km

# %%
def parse_response(return_json,query_name):
    return {
        "query_name":query_name,
        'formatted_address':return_json['formatted_address'],
        "lat":return_json['geometry']['location']['lat'],
        "lng":return_json['geometry']['location']['lng'],
    }

# %%
def n_gram(string):
    vectorizer = CountVectorizer(ngram_range=(1, 100),token_pattern = r"(?u)\b\w+\b")
    X = vectorizer.fit_transform([string])
    analyze = vectorizer.build_analyzer()
    return vectorizer.get_feature_names()

# %%
def query_from_geonames(candidate):
    resp=requests.get("https://www.geonames.org/search.html?q="+candidate+"&country=GT").text
    return "records found for" in resp or "record found for" in resp

# %%
def validate_place_name(string):
    n_grams=n_gram(string)
    return sum([query_from_geonames(i) for i in n_grams])

# %% [markdown]
# Define walker to traverse all the nodes, and generate text by each node

# %%
def walker(soup):
    result_list=[]
    if soup.name is not None:
        for child in soup.children:
            #process node
            #print(str(child.string))
#             if None != child.string:
#                 print()
#                 t=Text(str(child.extact()))
#                 print(t.pos_tags)
            result_list.append(str(child.string))
            result_list+=walker(child)
    return result_list

# %% [markdown]
# Processing Netherlands case

# %%
with open('../data/NL_html','r',encoding='UTF-8') as f:
    soup=BeautifulSoup(f.read())
    for script in soup(["script", "style"]):
        script.decompose()
    #print(soup)
    candidate_list=list(set(walker(soup)))

# %%
after_filter_nl=[]
name_candidate_nl=[]
for i in candidate_list:
    #print(i)
    print(re.match(r"^(?=.*[A-Za-z])(?=.*,).*$",i.replace('\n',''),re.M))
    i=" ".join(i.split())
    if re.match(r"^(?=.*[A-Za-z])(?=.*,).*$",i.replace('\n',''),re.M) and len(i)<100:
        after_filter_nl+=[i.replace('\n','')]
    elif re.match(r"^(?=.*[A-Za-z]).*$",i.replace('\n',''),re.M) and len(i)<50 and len(i)>3:
        name_candidate_nl.append(i)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 42), match='Wigstraat 15  Lelystad,  Flevoland 8223 EE'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 43), match='Bachlaan 7  Doetinchem,  Gelderland 7002 MZ'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 48), match='Nieuweweg 33b  Hoofddorp,  Noord-Holland 2132 CK'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 132), match='Niet-geclassificeerde cookies zijn cookies die we>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 53), match='Pieter Mondriaanstraat 11  Bergen Lb,  Limburg 58>
# None
# <re.Match object; span=(0, 51), match='H G Gooszenstraat 10  Deventer,  Overijssel 7415 >
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Achterberglaan 63  Uithoorn,  Noord-Holland 1422 >
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 39), match='De Insel 18  Brunssum,  Limburg 6442 AJ'>
# <re.Match object; span=(0, 45), match='Wagenmakerbaan 47  Almere,  Flevoland 1315 BC'>
# <re.Match object; span=(0, 57), match='Dennenhorst 22 a  Driebergen-Rijsenburg,  Utrecht>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 272), match="Verzamelt gegevens over gebruikersbezoeken aan de>
# None
# None
# <re.Match object; span=(0, 46), match='De Sterke Arm 10  Veenendaal,  Utrecht 3901 ER'>
# None
# None
# None
# <re.Match object; span=(0, 58), match='Adriaen Brouwerstraat 10  Haaksbergen,  Overijsse>
# None
# None
# None
# <re.Match object; span=(0, 56), match='Valkenburgerstraat 24  Amsterdam,  Noord-Holland >
# <re.Match object; span=(0, 41), match='De Waring 38  Hoogeveen,  Drenthe 7908 LE'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 56), match='Nicolaas Beetslaan 14  Zandvoort,  Noord-Holland >
# None
# None
# None
# <re.Match object; span=(0, 42), match='Veenhof 1955  Wijchen,  Gelderland 6604 DG'>
# None
# None
# None
# <re.Match object; span=(0, 53), match='Gebroeders van Doornelaan 63  Horst,  Limburg 596>
# <re.Match object; span=(0, 57), match='Dubbelsteynlaan West 43  Dordrecht,  Zuid-Holland>
# <re.Match object; span=(0, 44), match='Rijksvluchthaven 24  Heijen,  Limburg 6591BC'>
# None
# <re.Match object; span=(0, 52), match='Koninginneweg 3 a  Bodegraven,  Zuid-Holland 2411>
# None
# None
# <re.Match object; span=(0, 277), match='Chaos en ontreddering na de aanslagen in Nice en >
# <re.Match object; span=(0, 38), match='Oppers 58  Wolvega,  Friesland 8471 ZM'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 193), match='Voorkeurscookies zorgen ervoor dat een website in>
# <re.Match object; span=(0, 340), match='Deze cookie wordt gebruikt om gegevens over een b>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 170), match='Verzamelt gegevens over het aantal keren dat een >
# <re.Match object; span=(0, 49), match='Hueseplein 15  Amstelveen,  Noord-Holland 1185 HH>
# None
# None
# None
# <re.Match object; span=(0, 49), match='Van Haersoltelaan 1  Hasselt,  Overijssel 8061 EG>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 39), match='Kwartellaan 13  Zeist,  Utrecht 3704 ET'>
# <re.Match object; span=(0, 54), match='Oude Dieze 12  S-Hertogenbosch,  Noord-Brabant 52>
# None
# <re.Match object; span=(0, 52), match='Vredehofstraat 9 C  Hoorn Nh,  Noord-Holland 1624>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 43), match='Espelerweg 4  Emmeloord,  Flevoland 8303 HW'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 217), match="Bevat gegevens over gebruikersnavigatie, interact>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 72), match='Vincent van Goghstraat 4 6901 DK ZEVENAAR  Zevena>
# <re.Match object; span=(0, 40), match='Nijmeegseweg 40  Venlo,  Limburg 5916 PT'>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 38), match='Eendenkuil 1  Odoorn,  Drenthe 7873 BM'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Duivenstraat 70  Papendrecht,  Zuid-Holland 3353 >
# <re.Match object; span=(0, 43), match='Brahmsstraat 5  Zwolle,  Overijssel 8031 DB'>
# None
# <re.Match object; span=(0, 44), match='Oranjestraat 10  Panningen,  Limburg 5981 CB'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 35), match='Hertzdahlstraat 68, 6411 KD Heerlen'>
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Postbus 130  Bergen Nh,  Noord-Holland 1860 AC'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 57), match='Marnix Gijsenstraat 7  Sommelsdijk,  Zuid-Holland>
# None
# None
# <re.Match object; span=(0, 39), match='Koningsweg 2  Utrecht,  Utrecht 3582 GE'>
# None
# None
# <re.Match object; span=(0, 293), match='Je moet er niet aan denken: een trein die ontspoo>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 42), match='Boslaan 10A  Zuidhoorn,  Groningen 9801 HG'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 39), match='Omloop 42  Drachten,  Friesland 9201 CC'>
# None
# None
# <re.Match object; span=(0, 45), match='Elburgerweg 11  Nunspeet,  Gelderland 8071 TA'>
# None
# None
# None
# <re.Match object; span=(0, 36), match='Punt 6  Gouda,  Zuid-Holland 2801 PZ'>
# None
# None
# None
# <re.Match object; span=(0, 56), match='Dillenburg 2  Alphen Aan Den Rijn,  Zuid-Holland >
# None
# <re.Match object; span=(0, 41), match='Nobelstraat 51  Heerlen,  Limburg 6411 EL'>
# None
# None
# None
# None
# <re.Match object; span=(0, 47), match='Zilverstraat 2  Den Haag,  Zuid-Holland 2544 ER'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 48), match='Vergierdeweg 52  Haarlem,  Noord-Holland 2025 TK'>
# <re.Match object; span=(0, 64), match='Willem van Konijnenburglaan 6  Eindhoven,  Noord->
# None
# None
# None
# <re.Match object; span=(0, 268), match="Verzamelt gegevens over de bezoeken van de gebrui>
# None
# <re.Match object; span=(0, 49), match='Klein Vlaanderen 59  Middelburg,  Zeeland 4331 RG>
# None
# None
# None
# None
# <re.Match object; span=(0, 41), match='Postbus 164  Zeewolde,  Flevoland 3890 AD'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 38), match='Wolvenweg 27  Ruinen,  Drenthe 7963 BG'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Haarloseweg 2 -3  Borculo,  Gelderland 7271 BT'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 47), match='Hogendorpstraat 10  Dieren,  Gelderland 6951 ER'>
# <re.Match object; span=(0, 49), match='Van Sytzamalaan 3  Oldebroek,  Gelderland 8096 AR>
# <re.Match object; span=(0, 87), match='Gebruikt door het inhoudsnetwerk, Cloudflare, om >
# None
# <re.Match object; span=(0, 55), match='D. van de Arestraat 17  Vollenhove,  Overijssel 8>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 43), match='Eksterstraat 12  Benschop,  Utrecht 3405 WH'>
# None
# None
# <re.Match object; span=(0, 45), match='Apollolaan 1 B  Leiden,  Zuid-Holland 2324 BR'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Hoofdstraat 24 b  Kerkrade,  Limburg 6461 CR'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 50), match='Bankastraat 27  Den Helder,  Noord-Holland 1782 T>
# None
# None
# <re.Match object; span=(0, 55), match='Julianastraat 11  Oud-Beijerland,  Zuid-Holland 3>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Magnoliastraat 10  Vianen Ut,  Utrecht 4131 BB'>
# None
# None
# <re.Match object; span=(0, 48), match='Nijkerkerweg 119  Barneveld,  Gelderland 3771 LA'>
# None
# <re.Match object; span=(0, 33), match='Delft 73  Assen,  Drenthe 9406 GD'>
# None
# None
# <re.Match object; span=(0, 469), match='Als er brand is in je straat en je moet je huis u>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 53), match='De Plataan Vledderstraat 3F  Meppel,  Drenthe 794>
# None
# None
# None
# None
# <re.Match object; span=(0, 31), match='Postbus 28120, 2502 KC Den Haag'>
# None
# None
# <re.Match object; span=(0, 49), match='Burgemeester Penstraat 6  Baarn,  Utrecht 3741 AH>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 52), match='Gezellelaan 18 E  Roosendaal,  Noord-Brabant 4707>
# <re.Match object; span=(0, 40), match='Kramsvogel 42  Eijsden,  Limburg 6245 RE'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 53), match='Slobbegorsedijk 2  Heijningen,  Noord-Brabant 479>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 168), match='Deze cookie wordt gebruikt in de context van HTML>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 43), match='Golda Meirstraat 23  Goes,  Zeeland 4463 DC'>
# None
# None
# None
# <re.Match object; span=(0, 59), match='Damstraat 26  Hardinxveld-Giessendam,  Zuid-Holla>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 39), match='Hemelsley 20  Sittard,  Limburg 6136 HM'>
# None
# None
# <re.Match object; span=(0, 39), match='Nering Bögelstraat 62  Ommen,   7731 EM'>
# None
# <re.Match object; span=(0, 44), match='Molengriendweg 3  Roermond,  Limburg 6041 BN'>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 33), match='Plein 15  Rolde,  Drenthe 9451 BW'>
# None
# None
# None
# <re.Match object; span=(0, 37), match='Plataan 7  Megen,  Gelderland 5366 CJ'>
# <re.Match object; span=(0, 48), match='Evertsenstraat 1  Veghel,  Noord-Brabant 5463 HM'>
# None
# None
# <re.Match object; span=(0, 51), match='Kloosterstraat 16  Lemelerveld,  Overijssel 8152 >
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 342), match='Stel dat je je huis uit moet doordat er een gasle>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 42), match='Kerkstraat 20  Renswoude,  Utrecht 3927 BR'>
# None
# None
# <re.Match object; span=(0, 43), match='Lohuizerweg 18 -1  Epe,  Gelderland 8162 EX'>
# None
# None
# <re.Match object; span=(0, 61), match='Willem Dreesstraat 3  Bunschoten Spakenburg,  Utr>
# None
# None
# <re.Match object; span=(0, 37), match='Helmkruid 5  Gieten,  Drenthe 9461 LL'>
# <re.Match object; span=(0, 46), match='Constructieweg 6  Nieuwegein,  Utrecht 3433 NN'>
# <re.Match object; span=(0, 40), match='Keulseweg 39 A  Reuver,  Limburg 5953 HE'>
# <re.Match object; span=(0, 55), match='p/a Langerakstraat 16  Doornenburg,  Gelderland 6>
# None
# None
# <re.Match object; span=(0, 42), match='Selfhelpweg 2    Sneek,  Friesland 8607 AB'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 163), match='Deze cookie wordt gebruikt om informatie te verza>
# None
# <re.Match object; span=(0, 174), match="Verzamelt gegevens over de bezoeken van de gebrui>
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Slimpad 16 C  Heiloo,  Noord-Holland 1851 LB'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='De Wulp 69  Vriezenveen,  Overijssel 7671 ZN'>
# None
# None
# None
# None
# <re.Match object; span=(0, 45), match='Trimpad 4  Vlaardingen,  Zuid-Holland 3135 GA'>
# None
# None
# None
# <re.Match object; span=(0, 44), match='Cortenstraat 7  Maastricht,  Limburg 6211 HT'>
# None
# <re.Match object; span=(0, 254), match='Volgens de wet mogen wij cookies op uw apparaat o>
# None
# None
# None
# None
# <re.Match object; span=(0, 57), match='Frankenplantsoen 11  Wijk Bij Duurstede,  Utrecht>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 349), match='Steeds vaker gaan zomer in Nederland gepaard met >
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 40), match='Kinkenweg 13 A  Geleen,  Limburg 6166 AM'>
# None
# None
# <re.Match object; span=(0, 47), match='Geesterweg 25  Uitgeest,  Noord-Holland 1911 HK'>
# <re.Match object; span=(0, 41), match='Weglangen 6  Westerbork,  Drenthe 9431 HK'>
# None
# <re.Match object; span=(0, 38), match='Kerkstraat 1  Rhenen,  Utrecht 3911 LD'>
# <re.Match object; span=(0, 7), match='Bussum,'>
# None
# <re.Match object; span=(0, 411), match='Deze website maakt gebruik van cookies om je gebr>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Kaartgegevens ©2019 GeoBasis-DE/BKG (©2009), Goog>
# <re.Match object; span=(0, 56), match='Postadres: Heidenendstraat 21  Tegelen,  Limburg >
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Dordsedijk 7  Klazienaveen,  Drenthe 7891 NJ'>
# None
# None
# <re.Match object; span=(0, 50), match="'s Gravenlust 35  IJmuiden,  Noord-Holland 1981 A>
# None
# None
# <re.Match object; span=(0, 57), match='In de Korenmolen 30  Duivendrecht,  Noord-Holland>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Berkenlaan 1  Staphorst,  Overijssel 7951 CA'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 53), match='James Ensorstraat 3  Waalwijk,  Noord-Brabant 514>
# None
# <re.Match object; span=(0, 47), match='Schuitkant 5  Burgh-Haamstede,  Zeeland 4328 BE'>
# None
# <re.Match object; span=(0, 167), match='Deze cookie wordt gebruikt in de context van HTML>
# None
# <re.Match object; span=(0, 57), match='Van Heeckerenstraat 2 A  Wassenaar,  Zuid-Holland>
# None
# None
# None
# None
# <re.Match object; span=(0, 45), match='Klaverweide 20  Giesbeek,  Gelderland 6987 DB'>
# None
# <re.Match object; span=(0, 48), match='Nazarethstraat 144  Best,  Noord-Brabant 5683 AB'>
# None
# None
# None
# <re.Match object; span=(0, 62), match='Van Limburg Stirumstraat 1a  Geldermalsen,  Gelde>
# None
# <re.Match object; span=(0, 37), match='Heiweg 5  Malden,  Gelderland 6581 EA'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 55), match='Prins Hendrikkade 12  Katwijk Zh,  Zuid-Holland 2>
# None
# None
# <re.Match object; span=(0, 40), match='Kerkvaart 2  Mijdrecht,  Utrecht 3641 EP'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Hofkampstraat 102  Almelo,  Overijssel 7607 NJ'>
# None
# None
# None
# <re.Match object; span=(0, 48), match='Clauslaan 2 a  Zoetermeer,  Zuid-Holland 2713 VN'>
# None
# None
# None
# <re.Match object; span=(0, 34), match='Wijk 8 -2  Urk,  Flevoland 8321 TG'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 40), match='Slenerbrink 272  Emmen,  Drenthe 7812 HL'>
# <re.Match object; span=(0, 52), match='Lichtenbergerstraat 7 b  Landgraaf,  Limburg 6371>
# <re.Match object; span=(0, 185), match='Verzamelt gegevens over waar de gebruiker vandaan>
# None
# <re.Match object; span=(0, 49), match='Zeearendstraat 13  Petten,  Noord-Holland 1755 PK>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 49), match='Blokshekken 6  Oisterwijk,  Noord-Brabant 5061 HA>
# None
# <re.Match object; span=(0, 56), match='Willem de Zwijgerstraat 30  Rijssen,  Overijssel >
# None
# None
# None
# None
# <re.Match object; span=(0, 52), match='Leeuwenstraat 9 11  Rotterdam,  Zuid-Holland 3011>
# None
# None
# None
# <re.Match object; span=(0, 204), match='Verzamelt gegevens zoals het IP-adres van bezoeke>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 117), match='Gebruikt door Facebook om een reeks advertentiepr>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Mr. F.J. Haarmanweg 13  Terneuzen,  Zeeland 4538 >
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 49), match='Hoveniersland 22  Zaltbommel,  Gelderland 5301 VA>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 45), match='Eltensestraat 17  Duiven,  Gelderland 6922 JA'>
# None
# None
# None
# <re.Match object; span=(0, 48), match='Veenroede 21  Emmer-Compascuum,  Drenthe 7881 XM'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Edisonstraat 32C  Franeker,  Friesland 8801 PN'>
# None
# <re.Match object; span=(0, 52), match='Waterlandlaan 101  Purmerend,  Noord-Holland 1441>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 50), match='Noordpoort 10  Sint Maartensdijk,  Zeeland 4695 B>
# None
# None
# None
# None
# <re.Match object; span=(0, 46), match='Pelikaanstraat 17  Losser,  Overijssel 7581 SZ'>
# None
# None
# <re.Match object; span=(0, 40), match='De Gouwe 50  Dronten,  Flevoland 8253 PA'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 50), match='Karmel 225  Bergen Op Zoom,  Noord-Brabant 4613 B>
# None
# <re.Match object; span=(0, 43), match='Lange Haeg 189  Ermelo,  Gelderland 3853 EG'>
# None
# None
# <re.Match object; span=(0, 47), match='Hoge Steenweg 19  Breda,  Noord-Brabant 4811 CG'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Julianalaan 64  Maasbracht,  Limburg 6051 AV'>
# <re.Match object; span=(0, 6), match='Delft,'>
# None
# None
# <re.Match object; span=(0, 51), match='Gelukken 15 A  Valkenswaard,  Noord-Brabant 5552 >
# None
# <re.Match object; span=(0, 45), match='Torendreef 22  Bladel,  Noord-Brabant 5531 ET'>
# None
# None
# None
# <re.Match object; span=(0, 49), match='De Klapstaarten 5  Esbeek,  Noord-Brabant 5085 GA>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 34), match='Hoppad 17  Roden,  Drenthe 9301 PG'>
# None
# None
# <re.Match object; span=(0, 46), match='Doetinchemseweg 7  Zelhem,  Gelderland 7021 BP'>
# <re.Match object; span=(0, 61), match='Businesspark Friesland-West 42  Nijehaske,  Fries>
# None
# None
# <re.Match object; span=(0, 47), match='Van Galenstraat 40  Hattem,  Gelderland 8051 VC'>
# None
# None
# None
# <re.Match object; span=(0, 46), match='Hofakkers 26  Oosterhesselen,  Drenthe 7861 AS'>
# None
# <re.Match object; span=(0, 51), match='Nachtegaallaan 215  Helmond,  Noord-Brabant 5702 >
# None
# <re.Match object; span=(0, 10), match='Groningen,'>
# <re.Match object; span=(0, 152), match='Statistische cookies helpen eigenaren van website>
# None
# <re.Match object; span=(0, 44), match='Columbusweg 30  Amersfoort,  Utrecht 3814 WE'>
# <re.Match object; span=(0, 41), match='Oranjewal 28   Dokkum,  Friesland 9101 JV'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 44), match='Jamarstraat 11  Simpelveld,  Limburg 6369 ED'>
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 50), match='Karmel 225  BERGEN OP ZOOM,  Noord-Brabant 4613 B>
# None
# None
# <re.Match object; span=(0, 45), match='Plantageweg 4  Brielle,  Zuid-Holland 3232 LE'>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 43), match='Atoomweg 2 B  Groningen,  Groningen 9743 AK'>
# <re.Match object; span=(0, 37), match='Dijkhoeve 4  Houten,  Utrecht 3992 XV'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Otto van Reesweg 10  Culemborg,  Gelderland 4105 >
# None
# <re.Match object; span=(0, 60), match='Kapitein Rietbergflat 26  Zwijndrecht,  Zuid-Holl>
# None
# None
# None
# <re.Match object; span=(0, 50), match='Graaf Ottolaan 13  Oosterbeek,  Gelderland 6861 B>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 55), match='Burgemeester Leenstraat 25  Lochem,  Gelderland 7>
# <re.Match object; span=(0, 42), match='Bergweg 4  Venray,  Limburg 5801 EG Venray'>
# None
# None
# <re.Match object; span=(0, 287), match='Ben je op een festival in glas gaan staan? Word j>
# None
# None
# None
# None
# <re.Match object; span=(0, 50), match='Nordhornsestraat 64  Denekamp,  Overijssel 7591 B>
# None
# <re.Match object; span=(0, 40), match='Dorpsstraat 4  Havelte,  Drenthe 7971 CR'>
# None
# None
# None
# None
# <re.Match object; span=(0, 47), match='Saffier 16  Julianadorp,  Noord-Holland 1761 VD'>
# None
# <re.Match object; span=(0, 51), match='Duitslandstraat 7  Ijsselstein Ut,  Utrecht 3402 >
# None
# <re.Match object; span=(0, 44), match='Postbus 72  Naaldwijk,  Zuid-Holland 2670 AB'>
# None
# <re.Match object; span=(0, 46), match='Brummelkant 2  Stadskanaal,  Groningen 9502 BB'>
# None
# None
# None
# <re.Match object; span=(0, 51), match='Gasthuisstraat 78  Winterswijk,  Gelderland 7101 >
# <re.Match object; span=(0, 45), match='Beusakker 27  Someren,  Noord-Brabant 5712 MG'>
# <re.Match object; span=(0, 46), match='Wilhelminalaan 20  Kampen,  Overijssel 8262 DE'>
# None
# None
# <re.Match object; span=(0, 43), match='Bruelisstraat 21  Kapelle,  Zeeland 4421 CL'>
# None
# None
# <re.Match object; span=(0, 50), match='James Wattstraat 4  Leeuwarden,  Friesland 8912 A>
# <re.Match object; span=(0, 46), match='Bosstraat 5 B  Valkenburg Lb,  Limburg 6301 HM'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 42), match='Kloosterlaan 25  Goor,  Overijssel 7471 BA'>
# None
# None
# <re.Match object; span=(0, 54), match='Buiten de Veste 10  Schoonhoven,  Zuid-Holland 28>
# None
# <re.Match object; span=(0, 42), match='Vegelinsweg 6 B  Joure,  Friesland 8501 BA'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 47), match='Maltezerlaan 3  Harderwijk,  Gelderland 3842 AZ'>
# None
# None
# None
# <re.Match object; span=(0, 47), match='Cattepoelseweg 263  Arnhem,  Gelderland 6815 CD'>
# None
# <re.Match object; span=(0, 49), match='Havenstraat 5 b  Nijkerk Gld,  Gelderland 3861 VS>
# None
# None
# None
# <re.Match object; span=(0, 47), match='Schuttersweg 41  Apeldoorn,  Gelderland 7314 LD'>
# None
# None
# None
# None
# <re.Match object; span=(0, 47), match='Westdorplaan 132 a  Raalte,  Overijssel 8101 PP'>
# None
# None
# None
# None
# <re.Match object; span=(0, 42), match='Kromstraat 45  Oss,  Noord-Brabant 5345 AA'>
# None
# None
# None
# None
# <re.Match object; span=(0, 52), match='Ankerstraat 24  Oosterend Nh,  Noord-Holland 1794>
# None
# <re.Match object; span=(0, 45), match='Richter 44  Werkendam,  Noord-Brabant 4251 DB'>
# <re.Match object; span=(0, 46), match='Gelderselaan 14  Nijmegen,  Gelderland 6523 LJ'>
# <re.Match object; span=(0, 47), match='Coevorderweg 31  Slagharen,  Overijssel 7776 AC'>
# None
# <re.Match object; span=(0, 50), match='Leidekkersdreef 12  Apeldoorn,  Gelderland 7328 A>
# None
# None
# None
# <re.Match object; span=(0, 44), match='Maria-Louiselaan 11  Lopik,  Utrecht 3411 XS'>
# None
# None
# None
# <re.Match object; span=(0, 46), match='Blekerstraat 81  Enschede,  Overijssel 7513 DT'>
# None
# None
# <re.Match object; span=(0, 48), match='Centaurusweg 57  Tilburg,  Noord-Brabant 5015 TC'>
# None
# None
# None
# <re.Match object; span=(0, 45), match='Handelstraat 45  Eerbeek,  Gelderland 6961 AD'>
# <re.Match object; span=(0, 233), match='Noodzakelijke cookies helpen een website bruikbaa>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 49), match='Rembrandtplein 19  Nijverdal,  Overijssel 7442 KH>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 45), match='Postbus 440  Aalsmeer,  Noord-Holland 1430 AK'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Ackersdijkseweg 16  Delfgauw,  Zuid-Holland 2645 >
# <re.Match object; span=(0, 49), match='Rijpersweg 36  Oud Gastel,  Noord-Brabant 4751 AS>
# None
# <re.Match object; span=(0, 45), match='Sint Laurensweg 13  De Bilt,  Utrecht 3732 BA'>
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 49), match='Vredehofstraat 9 C  Hoorn,  Noord-Holland 1624 XG>
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 35), match='Bellweg 2  Beilen,  Drenthe 9411 PV'>
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 103), match="Verzamelt gegevens over de bezoeken van de gebrui>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 51), match='Klinkenbergerweg 30 C  Ede Gld,  Gelderland 6711 >
# None
# None
# <re.Match object; span=(0, 44), match='Marnixstraat 1  Hengelo,  Overijssel 7553 LC'>
# <re.Match object; span=(0, 48), match='Herenstraat 165  Voorburg,  Zuid-Holland 2271 CE'>
# None
# None
# <re.Match object; span=(0, 51), match='Schoolstraat 16  Beuningen Gld,  Gelderland 6641 >
# None
# None
# <re.Match object; span=(0, 45), match='Boerhaavestraat 15 A  Weert,  Limburg 6001 AV'>
# None
# <re.Match object; span=(0, 300), match='Jaarlijks doen in Nederland honderden slachtoffer>
# None
# None
# None
# <re.Match object; span=(0, 55), match='Hertog Aalbrechtweg 10  Alkmaar,  Noord-Holland 1>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 49), match='Karnemelkstraat 2A  Breda,  Noord-Brabant 4811 KJ>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 45), match='Vulcanusweg 263  Delft,  Zuid-Holland 2624 AV'>

# %%
after_filter_nl
# Out:
# ['Wigstraat 15 Lelystad, Flevoland 8223 EE',
#  'Bachlaan 7 Doetinchem, Gelderland 7002 MZ',
#  'Nieuweweg 33b Hoofddorp, Noord-Holland 2132 CK',
#  'Pieter Mondriaanstraat 11 Bergen Lb, Limburg 5854GA',
#  'H G Gooszenstraat 10 Deventer, Overijssel 7415 CL',
#  'Achterberglaan 63 Uithoorn, Noord-Holland 1422 CX',
#  'De Insel 18 Brunssum, Limburg 6442 AJ',
#  'Wagenmakerbaan 47 Almere, Flevoland 1315 BC',
#  'Dennenhorst 22 a Driebergen-Rijsenburg, Utrecht 3972 GM',
#  'De Sterke Arm 10 Veenendaal, Utrecht 3901 ER',
#  'Adriaen Brouwerstraat 10 Haaksbergen, Overijssel 7482 ZK',
#  'Valkenburgerstraat 24 Amsterdam, Noord-Holland 1011 LZ',
#  'De Waring 38 Hoogeveen, Drenthe 7908 LE',
#  'Nicolaas Beetslaan 14 Zandvoort, Noord-Holland 2041 NN',
#  'Veenhof 1955 Wijchen, Gelderland 6604 DG',
#  'Gebroeders van Doornelaan 63 Horst, Limburg 5961 BB',
#  'Dubbelsteynlaan West 43 Dordrecht, Zuid-Holland 3319 EK',
#  'Rijksvluchthaven 24 Heijen, Limburg 6591BC',
#  'Koninginneweg 3 a Bodegraven, Zuid-Holland 2411 XK',
#  'Oppers 58 Wolvega, Friesland 8471 ZM',
#  'Hueseplein 15 Amstelveen, Noord-Holland 1185 HH',
#  'Van Haersoltelaan 1 Hasselt, Overijssel 8061 EG',
#  'Kwartellaan 13 Zeist, Utrecht 3704 ET',
#  'Oude Dieze 12 S-Hertogenbosch, Noord-Brabant 5211 KV',
#  'Vredehofstraat 9 C Hoorn Nh, Noord-Holland 1624 XG',
#  'Espelerweg 4 Emmeloord, Flevoland 8303 HW',
#  'Vincent van Goghstraat 4 6901 DK ZEVENAAR Zevenaar, Gelderland 6901 DK',
#  'Nijmeegseweg 40 Venlo, Limburg 5916 PT',
#  'Eendenkuil 1 Odoorn, Drenthe 7873 BM',
#  'Duivenstraat 70 Papendrecht, Zuid-Holland 3353 AG',
#  'Brahmsstraat 5 Zwolle, Overijssel 8031 DB',
#  'Oranjestraat 10 Panningen, Limburg 5981 CB',
#  'Hertzdahlstraat 68, 6411 KD Heerlen',
#  'Postbus 130 Bergen Nh, Noord-Holland 1860 AC',
#  'Marnix Gijsenstraat 7 Sommelsdijk, Zuid-Holland 3245 ME',
#  'Koningsweg 2 Utrecht, Utrecht 3582 GE',
#  'Boslaan 10A Zuidhoorn, Groningen 9801 HG',
#  'Omloop 42 Drachten, Friesland 9201 CC',
#  'Elburgerweg 11 Nunspeet, Gelderland 8071 TA',
#  'Punt 6 Gouda, Zuid-Holland 2801 PZ',
#  'Dillenburg 2 Alphen Aan Den Rijn, Zuid-Holland 2404 EV',
#  'Nobelstraat 51 Heerlen, Limburg 6411 EL',
#  'Zilverstraat 2 Den Haag, Zuid-Holland 2544 ER',
#  'Vergierdeweg 52 Haarlem, Noord-Holland 2025 TK',
#  'Willem van Konijnenburglaan 6 Eindhoven, Noord-Brabant 5613 DW',
#  'Klein Vlaanderen 59 Middelburg, Zeeland 4331 RG',
#  'Postbus 164 Zeewolde, Flevoland 3890 AD',
#  'Wolvenweg 27 Ruinen, Drenthe 7963 BG',
#  'Haarloseweg 2 -3 Borculo, Gelderland 7271 BT',
#  'Hogendorpstraat 10 Dieren, Gelderland 6951 ER',
#  'Van Sytzamalaan 3 Oldebroek, Gelderland 8096 AR',
#  'Gebruikt door het inhoudsnetwerk, Cloudflare, om vertrouwd webverkeer te identificeren.',
#  'D. van de Arestraat 17 Vollenhove, Overijssel 8325 GJ',
#  'Eksterstraat 12 Benschop, Utrecht 3405 WH',
#  'Apollolaan 1 B Leiden, Zuid-Holland 2324 BR',
#  'Hoofdstraat 24 b Kerkrade, Limburg 6461 CR',
#  'Bankastraat 27 Den Helder, Noord-Holland 1782 TA',
#  'Julianastraat 11 Oud-Beijerland, Zuid-Holland 3262 SH',
#  'Magnoliastraat 10 Vianen Ut, Utrecht 4131 BB',
#  'Nijkerkerweg 119 Barneveld, Gelderland 3771 LA',
#  'Delft 73 Assen, Drenthe 9406 GD',
#  'De Plataan Vledderstraat 3F Meppel, Drenthe 7941 LC',
#  'Postbus 28120, 2502 KC Den Haag',
#  'Burgemeester Penstraat 6 Baarn, Utrecht 3741 AH',
#  'Gezellelaan 18 E Roosendaal, Noord-Brabant 4707 CD',
#  'Kramsvogel 42 Eijsden, Limburg 6245 RE',
#  'Slobbegorsedijk 2 Heijningen, Noord-Brabant 4794 RR',
#  'Golda Meirstraat 23 Goes, Zeeland 4463 DC',
#  'Damstraat 26 Hardinxveld-Giessendam, Zuid-Holland 3371 AD',
#  'Hemelsley 20 Sittard, Limburg 6136 HM',
#  'Nering Bögelstraat 62 Ommen, 7731 EM',
#  'Molengriendweg 3 Roermond, Limburg 6041 BN',
#  'Plein 15 Rolde, Drenthe 9451 BW',
#  'Plataan 7 Megen, Gelderland 5366 CJ',
#  'Evertsenstraat 1 Veghel, Noord-Brabant 5463 HM',
#  'Kloosterstraat 16 Lemelerveld, Overijssel 8152 AP',
#  'Kerkstraat 20 Renswoude, Utrecht 3927 BR',
#  'Lohuizerweg 18 -1 Epe, Gelderland 8162 EX',
#  'Willem Dreesstraat 3 Bunschoten Spakenburg, Utrecht 3752 AX',
#  'Helmkruid 5 Gieten, Drenthe 9461 LL',
#  'Constructieweg 6 Nieuwegein, Utrecht 3433 NN',
#  'Keulseweg 39 A Reuver, Limburg 5953 HE',
#  'p/a Langerakstraat 16 Doornenburg, Gelderland 6686 CE',
#  'Selfhelpweg 2 Sneek, Friesland 8607 AB',
#  'Slimpad 16 C Heiloo, Noord-Holland 1851 LB',
#  'De Wulp 69 Vriezenveen, Overijssel 7671 ZN',
#  'Trimpad 4 Vlaardingen, Zuid-Holland 3135 GA',
#  'Cortenstraat 7 Maastricht, Limburg 6211 HT',
#  'Frankenplantsoen 11 Wijk Bij Duurstede, Utrecht 3962 CG',
#  'Kinkenweg 13 A Geleen, Limburg 6166 AM',
#  'Geesterweg 25 Uitgeest, Noord-Holland 1911 HK',
#  'Weglangen 6 Westerbork, Drenthe 9431 HK',
#  'Kerkstraat 1 Rhenen, Utrecht 3911 LD',
#  'Bussum,',
#  'Kaartgegevens ©2019 GeoBasis-DE/BKG (©2009), Google',
#  'Postadres: Heidenendstraat 21 Tegelen, Limburg 5932 XV',
#  'Dordsedijk 7 Klazienaveen, Drenthe 7891 NJ',
#  "'s Gravenlust 35 IJmuiden, Noord-Holland 1981 AE",
#  'In de Korenmolen 30 Duivendrecht, Noord-Holland 1115 GP',
#  'Berkenlaan 1 Staphorst, Overijssel 7951 CA',
#  'James Ensorstraat 3 Waalwijk, Noord-Brabant 5143 HC',
#  'Schuitkant 5 Burgh-Haamstede, Zeeland 4328 BE',
#  'Van Heeckerenstraat 2 A Wassenaar, Zuid-Holland 2242 GX',
#  'Klaverweide 20 Giesbeek, Gelderland 6987 DB',
#  'Nazarethstraat 144 Best, Noord-Brabant 5683 AB',
#  'Van Limburg Stirumstraat 1a Geldermalsen, Gelderland 4191 GM',
#  'Heiweg 5 Malden, Gelderland 6581 EA',
#  'Prins Hendrikkade 12 Katwijk Zh, Zuid-Holland 2225 TZ',
#  'Kerkvaart 2 Mijdrecht, Utrecht 3641 EP',
#  'Hofkampstraat 102 Almelo, Overijssel 7607 NJ',
#  'Clauslaan 2 a Zoetermeer, Zuid-Holland 2713 VN',
#  'Wijk 8 -2 Urk, Flevoland 8321 TG',
#  'Slenerbrink 272 Emmen, Drenthe 7812 HL',
#  'Lichtenbergerstraat 7 b Landgraaf, Limburg 6371 AS',
#  'Zeearendstraat 13 Petten, Noord-Holland 1755 PK',
#  'Blokshekken 6 Oisterwijk, Noord-Brabant 5061 HA',
#  'Willem de Zwijgerstraat 30 Rijssen, Overijssel 7462 HJ',
#  'Leeuwenstraat 9 11 Rotterdam, Zuid-Holland 3011 AL',
#  'Mr. F.J. Haarmanweg 13 Terneuzen, Zeeland 4538 AM',
#  'Hoveniersland 22 Zaltbommel, Gelderland 5301 VA',
#  'Eltensestraat 17 Duiven, Gelderland 6922 JA',
#  'Veenroede 21 Emmer-Compascuum, Drenthe 7881 XM',
#  'Edisonstraat 32C Franeker, Friesland 8801 PN',
#  'Waterlandlaan 101 Purmerend, Noord-Holland 1441 RT',
#  'Noordpoort 10 Sint Maartensdijk, Zeeland 4695 BX',
#  'Pelikaanstraat 17 Losser, Overijssel 7581 SZ',
#  'De Gouwe 50 Dronten, Flevoland 8253 PA',
#  'Karmel 225 Bergen Op Zoom, Noord-Brabant 4613 BS',
#  'Lange Haeg 189 Ermelo, Gelderland 3853 EG',
#  'Hoge Steenweg 19 Breda, Noord-Brabant 4811 CG',
#  'Julianalaan 64 Maasbracht, Limburg 6051 AV',
#  'Delft,',
#  'Gelukken 15 A Valkenswaard, Noord-Brabant 5552 LD',
#  'Torendreef 22 Bladel, Noord-Brabant 5531 ET',
#  'De Klapstaarten 5 Esbeek, Noord-Brabant 5085 GA',
#  'Hoppad 17 Roden, Drenthe 9301 PG',
#  'Doetinchemseweg 7 Zelhem, Gelderland 7021 BP',
#  'Businesspark Friesland-West 42 Nijehaske, Friesland 8466 SL',
#  'Van Galenstraat 40 Hattem, Gelderland 8051 VC',
#  'Hofakkers 26 Oosterhesselen, Drenthe 7861 AS',
#  'Nachtegaallaan 215 Helmond, Noord-Brabant 5702 KM',
#  'Groningen,',
#  'Columbusweg 30 Amersfoort, Utrecht 3814 WE',
#  'Oranjewal 28 Dokkum, Friesland 9101 JV',
#  'Jamarstraat 11 Simpelveld, Limburg 6369 ED',
#  'Karmel 225 BERGEN OP ZOOM, Noord-Brabant 4613 BS',
#  'Plantageweg 4 Brielle, Zuid-Holland 3232 LE',
#  'Atoomweg 2 B Groningen, Groningen 9743 AK',
#  'Dijkhoeve 4 Houten, Utrecht 3992 XV',
#  'Otto van Reesweg 10 Culemborg, Gelderland 4105 AA',
#  'Kapitein Rietbergflat 26 Zwijndrecht, Zuid-Holland 3333 CA',
#  'Graaf Ottolaan 13 Oosterbeek, Gelderland 6861 BS',
#  'Burgemeester Leenstraat 25 Lochem, Gelderland 7242 AA',
#  'Bergweg 4 Venray, Limburg 5801 EG Venray',
#  'Nordhornsestraat 64 Denekamp, Overijssel 7591 BH',
#  'Dorpsstraat 4 Havelte, Drenthe 7971 CR',
#  'Saffier 16 Julianadorp, Noord-Holland 1761 VD',
#  'Duitslandstraat 7 Ijsselstein Ut, Utrecht 3402 GH',
#  'Postbus 72 Naaldwijk, Zuid-Holland 2670 AB',
#  'Brummelkant 2 Stadskanaal, Groningen 9502 BB',
#  'Gasthuisstraat 78 Winterswijk, Gelderland 7101 DX',
#  'Beusakker 27 Someren, Noord-Brabant 5712 MG',
#  'Wilhelminalaan 20 Kampen, Overijssel 8262 DE',
#  'Bruelisstraat 21 Kapelle, Zeeland 4421 CL',
#  'James Wattstraat 4 Leeuwarden, Friesland 8912 AR',
#  'Bosstraat 5 B Valkenburg Lb, Limburg 6301 HM',
#  'Kloosterlaan 25 Goor, Overijssel 7471 BA',
#  'Buiten de Veste 10 Schoonhoven, Zuid-Holland 2871 GE',
#  'Vegelinsweg 6 B Joure, Friesland 8501 BA',
#  'Maltezerlaan 3 Harderwijk, Gelderland 3842 AZ',
#  'Cattepoelseweg 263 Arnhem, Gelderland 6815 CD',
#  'Havenstraat 5 b Nijkerk Gld, Gelderland 3861 VS',
#  'Schuttersweg 41 Apeldoorn, Gelderland 7314 LD',
#  'Westdorplaan 132 a Raalte, Overijssel 8101 PP',
#  'Kromstraat 45 Oss, Noord-Brabant 5345 AA',
#  'Ankerstraat 24 Oosterend Nh, Noord-Holland 1794 BJ',
#  'Richter 44 Werkendam, Noord-Brabant 4251 DB',
#  'Gelderselaan 14 Nijmegen, Gelderland 6523 LJ',
#  'Coevorderweg 31 Slagharen, Overijssel 7776 AC',
#  'Leidekkersdreef 12 Apeldoorn, Gelderland 7328 AT',
#  'Maria-Louiselaan 11 Lopik, Utrecht 3411 XS',
#  'Blekerstraat 81 Enschede, Overijssel 7513 DT',
#  'Centaurusweg 57 Tilburg, Noord-Brabant 5015 TC',
#  'Handelstraat 45 Eerbeek, Gelderland 6961 AD',
#  'Rembrandtplein 19 Nijverdal, Overijssel 7442 KH',
#  'Postbus 440 Aalsmeer, Noord-Holland 1430 AK',
#  'Ackersdijkseweg 16 Delfgauw, Zuid-Holland 2645 EB',
#  'Rijpersweg 36 Oud Gastel, Noord-Brabant 4751 AS',
#  'Sint Laurensweg 13 De Bilt, Utrecht 3732 BA',
#  'Vredehofstraat 9 C Hoorn, Noord-Holland 1624 XG',
#  'Bellweg 2 Beilen, Drenthe 9411 PV',
#  'Klinkenbergerweg 30 C Ede Gld, Gelderland 6711 MK',
#  'Marnixstraat 1 Hengelo, Overijssel 7553 LC',
#  'Herenstraat 165 Voorburg, Zuid-Holland 2271 CE',
#  'Schoolstraat 16 Beuningen Gld, Gelderland 6641 EV',
#  'Boerhaavestraat 15 A Weert, Limburg 6001 AV',
#  'Hertog Aalbrechtweg 10 Alkmaar, Noord-Holland 1823 DL',
#  'Karnemelkstraat 2A Breda, Noord-Brabant 4811 KJ',
#  'Vulcanusweg 263 Delft, Zuid-Holland 2624 AV']

# %% [markdown]
# Processing Guatemala case

# %%
with open('../data/GT_html','r',encoding='UTF-8') as f:
    soup=BeautifulSoup(f.read())
    for script in soup(["script", "style"]):
        script.decompose()
    #print(soup)
    candidate_list_gt=list(set(walker(soup)))

# %%
after_filter_gt=[]
name_candidate_gt=[]
for i in candidate_list_gt:
    #print(i)
    #print(re.match(r"^(?=.*[A-Za-z])(?=.*,).*$",i.replace('\n',''),re.M))
    i=" ".join(i.split())
    #print(i)
    if re.match(r"^(?=.*[A-Za-z])(?=.*,).*$",i.replace('\n',''),re.M) and len(i)<100:
        #print(i)
        after_filter_gt+=[i.replace('\n','')]
    elif re.match(r"^(?=.*[A-Za-z]).*$",i.replace('\n',''),re.M) and len(i)<50 and len(i)>3:
        name_candidate_gt.append(i)

# %%
len([i for i in name_candidate_gt if 'Delegación' in i])
# Out:
# 20

# %% [markdown]
# use Google map api to check whether candidates are real location

# %%
client=googlemaps.Client("AIzaSyBnB3duxMNxArGL7wu9nWp9aOtV7lKx1Ao")

# %%
client.geocode('Delegación Tecún Umán',region='gt')
# Out:
# [{'address_components': [{'long_name': 'Ciudad Tecun Uman',
#     'short_name': 'Ciudad Tecun Uman',
#     'types': ['locality', 'political']},
#    {'long_name': 'San Marcos Department',
#     'short_name': 'San Marcos Department',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'GT',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Ciudad Tecun Uman, Guatemala',
#   'geometry': {'location': {'lat': 14.6777526, 'lng': -92.1418964},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 14.6791015802915,
#      'lng': -92.14054741970848},
#     'southwest': {'lat': 14.6764036197085, 'lng': -92.14324538029149}}},
#   'place_id': 'ChIJD9sIhstqjoUR0Mln8mpFuNc',
#   'plus_code': {'compound_code': 'MVH5+46 Ciudad Tecun Uman, Guatemala',
#    'global_code': '7669MVH5+46'},
#   'types': ['establishment', 'hospital', 'point_of_interest']}]

# %%
client.geocode('1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos ',region='gt')
# Out:
# [{'address_components': [{'long_name': '4',
#     'short_name': '4',
#     'types': ['street_number']},
#    {'long_name': '1 Avenida', 'short_name': '1 Ave', 'types': ['route']},
#    {'long_name': 'Zona 10',
#     'short_name': 'Zona 10',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Guatemala',
#     'short_name': 'Guate',
#     'types': ['locality', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'Guatemala',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'GT',
#     'types': ['country', 'political']}],
#   'formatted_address': '1 Avenida 4, Guatemala',
#   'geometry': {'location': {'lat': 14.6029046, 'lng': -90.5148114},
#    'location_type': 'RANGE_INTERPOLATED',
#    'viewport': {'northeast': {'lat': 14.6042535802915,
#      'lng': -90.51346241970849},
#     'southwest': {'lat': 14.6015556197085, 'lng': -90.51616038029151}}},
#   'partial_match': True,
#   'place_id': 'EhYxIEF2ZW5pZGEgNCwgR3VhdGVtYWxhIhoSGAoUChIJkwd7s8-jiYURqKrWFloUj5UQBA',
#   'types': ['street_address']},
#  {'address_components': [{'long_name': 'Ayutla',
#     'short_name': 'Ayutla',
#     'types': ['locality', 'political']},
#    {'long_name': 'San Marcos Department',
#     'short_name': 'San Marcos Department',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'GT',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Ayutla, Guatemala',
#   'geometry': {'location': {'lat': 14.68003, 'lng': -92.132172},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.6908235, 'lng': -92.11616459999999},
#     'southwest': {'lat': 14.669236, 'lng': -92.14817939999999}}},
#   'partial_match': True,
#   'place_id': 'ChIJda9ST8RqjoUR2vHpPs-A7wE',
#   'types': ['locality', 'political']}]

# %%
def query_geocode(name,region):
    response=client.geocode(name,region=region) 
    if len(response)>0:
        return (name,response)

# %%
addresses_list_gt_google=[query_geocode(i,region='gt')  for i in after_filter_gt]

# %%
name_list_gt_google=[query_geocode(i,region='gt')  for i in name_candidate_gt]

# %%
import pickle

# %%
with open('../data/name_list_gt_google.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(name_list_gt_google, f, pickle.HIGHEST_PROTOCOL)
with open('../data/addresses_list_gt_google.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(addresses_list_gt_google, f, pickle.HIGHEST_PROTOCOL)

# %%
name_list_gt_google=pickle.load(open('../data/name_list_gt_google.pickle','rb'))
addresses_list_gt_google=pickle.load(open("../data/addresses_list_gt_google.pickle",'rb'))

# %%
addresses_list_gt=[i for i in addresses_list_gt_google if i and validate_place_name(i[0]) and not re.search("[\U00010000-\U0010ffff]",i[0],flags=re.UNICODE)]
name_list_gt=[i for i in name_list_gt_google if i and validate_place_name(i[0]) and not re.search("[\U00010000-\U0010ffff]",i[0],flags=re.UNICODE) ]

# %%
for i in name_list_gt:
    print(i)
# Out:
# ('Delegación San Marcos', [{'address_components': [{'long_name': 'San Marcos', 'short_name': 'San Marcos', 'types': ['locality', 'political']}, {'long_name': 'San Marcos Department', 'short_name': 'San Marcos Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'San Marcos, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.9770683, 'lng': -91.78625489999999}, 'southwest': {'lat': 14.9490971, 'lng': -91.8162632}}, 'location': {'lat': 14.9609782, 'lng': -91.80745859999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.9770683, 'lng': -91.78625489999999}, 'southwest': {'lat': 14.9490971, 'lng': -91.8162632}}}, 'place_id': 'ChIJD5VGAeOAjoURxqtL17hFalM', 'types': ['locality', 'political']}, {'address_components': [{'long_name': 'San Marcos Department', 'short_name': 'San Marcos Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'San Marcos Department, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 15.432205, 'lng': -91.58420199999999}, 'southwest': {'lat': 14.484004, 'lng': -92.24149299999999}}, 'location': {'lat': 14.9309569, 'lng': -91.9099238}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 15.432205, 'lng': -91.58420199999999}, 'southwest': {'lat': 14.484004, 'lng': -92.24149299999999}}}, 'place_id': 'ChIJda9ST8RqjoURoTFH6ypzp54', 'types': ['administrative_area_level_1', 'political']}])
# ('Delegación Chiquimula', [{'address_components': [{'long_name': 'Chiquimula', 'short_name': 'Chiquimula', 'types': ['locality', 'political']}, {'long_name': 'Chiquimula Department', 'short_name': 'Chiquimula Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Chiquimula, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.8176195, 'lng': -89.51448309999999}, 'southwest': {'lat': 14.7463474, 'lng': -89.56295019999999}}, 'location': {'lat': 14.7924897, 'lng': -89.5450458}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.8176195, 'lng': -89.51448309999999}, 'southwest': {'lat': 14.7463474, 'lng': -89.56295019999999}}}, 'place_id': 'ChIJtcKOHX4wYo8R59Gzo2KNUus', 'types': ['locality', 'political']}])
# ('Contactenos | Cruz Roja Guatemalteca', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'geometry': {'location': {'lat': 14.6452757, 'lng': -90.5106878}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.6466246802915, 'lng': -90.50933881970849}, 'southwest': {'lat': 14.6439267197085, 'lng': -90.5120367802915}}}, 'place_id': 'ChIJW54vPBKiiYUR-EtI2ZCPUO4', 'plus_code': {'compound_code': 'JFWQ+4P Guatemala City, Guatemala', 'global_code': '766FJFWQ+4P'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación El Palmar', [{'address_components': [{'long_name': 'El Palmar, Quetzaltenango', 'short_name': 'El Palmar, Quetzaltenango', 'types': ['locality', 'political']}, {'long_name': 'Nuevo Palmar', 'short_name': 'Nuevo Palmar', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Suchitepequez', 'short_name': 'Suchitepequez', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'geometry': {'location': {'lat': 14.6479532, 'lng': -91.5568436}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.6493021802915, 'lng': -91.55549461970848}, 'southwest': {'lat': 14.6466042197085, 'lng': -91.55819258029149}}}, 'place_id': 'ChIJwUGdKdTqjoURJF1Kor7hal0', 'plus_code': {'compound_code': 'JCXV+57 El Palmar, Quetzaltenango, Guatemala', 'global_code': '766CJCXV+57'}, 'types': ['doctor', 'establishment', 'health', 'point_of_interest']}])
# ('Sede Central', [{'address_components': [{'long_name': '12-54', 'short_name': '12-54', 'types': ['street_number']}, {'long_name': '12 Avenida', 'short_name': '12 Avenida', 'types': ['route']}, {'long_name': 'Zona 1', 'short_name': 'Zona 1', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}, {'long_name': '01001', 'short_name': '01001', 'types': ['postal_code']}], 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'geometry': {'location': {'lat': 14.6353845, 'lng': -90.50777939999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 14.6367334802915, 'lng': -90.5064304197085}, 'southwest': {'lat': 14.6340355197085, 'lng': -90.5091283802915}}}, 'place_id': 'ChIJ1d7GXhWiiYUR3OOHiT1CJRY', 'plus_code': {'compound_code': 'JFPR+5V Guatemala City, Guatemala', 'global_code': '766FJFPR+5V'}, 'types': ['establishment', 'local_government_office', 'point_of_interest']}])
# ('Delegación Jalapa', [{'address_components': [{'long_name': 'Jalapa', 'short_name': 'Jalapa', 'types': ['locality', 'political']}, {'long_name': 'Jalapa Department', 'short_name': 'Jalapa Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Jalapa, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.6490293, 'lng': -89.97193329999999}, 'southwest': {'lat': 14.6230361, 'lng': -90.0112438}}, 'location': {'lat': 14.6325483, 'lng': -89.9930052}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.6490293, 'lng': -89.97193329999999}, 'southwest': {'lat': 14.6230361, 'lng': -90.0112438}}}, 'partial_match': True, 'place_id': 'ChIJN4BdlWd1Yo8RpimIfLzAxQA', 'types': ['locality', 'political']}])
# ('#Cruz', [{'address_components': [{'long_name': '2a Calle', 'short_name': '2a Calle', 'types': ['route']}, {'long_name': 'Cobán', 'short_name': 'Cobán', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'geometry': {'location': {'lat': 15.469403, 'lng': -90.3718126}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.4707519802915, 'lng': -90.3704636197085}, 'southwest': {'lat': 15.4680540197085, 'lng': -90.37316158029151}}}, 'place_id': 'ChIJYyVqvTNBioURYz1eRrYxIHU', 'plus_code': {'compound_code': 'FJ9H+Q7 Cobán, Guatemala', 'global_code': '767FFJ9H+Q7'}, 'types': ['establishment', 'health', 'point_of_interest']}, {'address_components': [{'long_name': 'Cobán', 'short_name': 'Cobán', 'types': ['locality', 'political']}, {'long_name': 'Zona 4', 'short_name': 'Zona 4', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Alta Verapaz Department', 'short_name': 'Alta Verapaz Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Cobán, Guatemala', 'geometry': {'location': {'lat': 15.4706183, 'lng': -90.3721394}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.4719672802915, 'lng': -90.37079041970848}, 'southwest': {'lat': 15.4692693197085, 'lng': -90.37348838029149}}}, 'place_id': 'ChIJGy27hjNBioURFOoSKabLjh4', 'plus_code': {'compound_code': 'FJCH+64 Cobán, Guatemala', 'global_code': '767FFJCH+64'}, 'types': ['establishment', 'health', 'pharmacy', 'point_of_interest', 'store']}])
# ('Delegación Sacapulas', [{'address_components': [{'long_name': 'Sacapulas', 'short_name': 'Sacapulas', 'types': ['locality', 'political']}, {'long_name': 'Quiché Department', 'short_name': 'Quiché Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Sacapulas, Guatemala', 'geometry': {'location': {'lat': 15.2895072, 'lng': -91.0891163}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.2908561802915, 'lng': -91.0877673197085}, 'southwest': {'lat': 15.2881582197085, 'lng': -91.09046528029151}}}, 'place_id': 'ChIJ0dYkTpjxi4URXgFG8g3E7KU', 'plus_code': {'compound_code': '7WQ6+R9 Sacapulas, Guatemala', 'global_code': '767C7WQ6+R9'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Tecún Umán', [{'address_components': [{'long_name': 'Ciudad Tecun Uman', 'short_name': 'Ciudad Tecun Uman', 'types': ['locality', 'political']}, {'long_name': 'San Marcos Department', 'short_name': 'San Marcos Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'geometry': {'location': {'lat': 14.6777526, 'lng': -92.1418964}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.6791015802915, 'lng': -92.14054741970848}, 'southwest': {'lat': 14.6764036197085, 'lng': -92.14324538029149}}}, 'place_id': 'ChIJD9sIhstqjoUR0Mln8mpFuNc', 'plus_code': {'compound_code': 'MVH5+46 Ciudad Tecun Uman, Guatemala', 'global_code': '7669MVH5+46'}, 'types': ['establishment', 'hospital', 'point_of_interest']}])
# ('Copyright © 2015 - Cruz Roja Guatemalteca', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'geometry': {'location': {'lat': 14.6452757, 'lng': -90.5106878}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.6466246802915, 'lng': -90.50933881970849}, 'southwest': {'lat': 14.6439267197085, 'lng': -90.5120367802915}}}, 'place_id': 'ChIJW54vPBKiiYUR-EtI2ZCPUO4', 'plus_code': {'compound_code': 'JFWQ+4P Guatemala City, Guatemala', 'global_code': '766FJFWQ+4P'}, 'types': ['establishment', 'point_of_interest']}])
# ('Nombre Completo', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 17.815697, 'lng': -88.1982001}, 'southwest': {'lat': 13.63, 'lng': -92.2714}}, 'location': {'lat': 15.783471, 'lng': -90.23075899999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 17.815697, 'lng': -88.1982001}, 'southwest': {'lat': 13.63, 'lng': -92.2714}}}, 'place_id': 'ChIJa1DnNlATiIURu9WEWzcrmDU', 'types': ['country', 'political']}])
# ('Delegación Tejutla', [{'address_components': [{'long_name': '4', 'short_name': '4', 'types': ['street_number']}, {'long_name': 'Avenida 3-71', 'short_name': 'Avenida 3-71', 'types': ['route']}, {'long_name': 'Tejutla', 'short_name': 'Tejutla', 'types': ['locality', 'political']}, {'long_name': 'San Marcos', 'short_name': 'San Marcos', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'geometry': {'location': {'lat': 15.1209353, 'lng': -91.80667799999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 15.1222842802915, 'lng': -91.8053290197085}, 'southwest': {'lat': 15.1195863197085, 'lng': -91.8080269802915}}}, 'place_id': 'ChIJ8W5hz50sjIURrwSmb9i2XaM', 'plus_code': {'compound_code': '45CV+98 Tejutla, Guatemala', 'global_code': '767C45CV+98'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Coatepeque', [{'address_components': [{'long_name': 'Coatepeque', 'short_name': 'Coatepeque', 'types': ['locality', 'political']}, {'long_name': 'Quetzaltenango', 'short_name': 'Quetzaltenango', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'geometry': {'location': {'lat': 14.707494, 'lng': -91.86847780000001}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.7088429802915, 'lng': -91.86712881970851}, 'southwest': {'lat': 14.7061450197085, 'lng': -91.86982678029152}}}, 'place_id': 'ChIJQ2uTUhlhjoUR5Uxy9wW8dzg', 'plus_code': {'compound_code': 'P44J+XJ Coatepeque, Guatemala', 'global_code': '766CP44J+XJ'}, 'types': ['establishment', 'local_government_office', 'point_of_interest']}])
# ('Comité Internacional de la Cruz Roja', [{'address_components': [{'long_name': '11-28', 'short_name': '11-28', 'types': ['street_number']}, {'long_name': '11 Calle', 'short_name': '11 Calle', 'types': ['route']}, {'long_name': 'Zona 1', 'short_name': 'Zona 1', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '11 Calle 11-28, Guatemala', 'geometry': {'location': {'lat': 14.6371215, 'lng': -90.5078604}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 14.6384704802915, 'lng': -90.50651141970849}, 'southwest': {'lat': 14.6357725197085, 'lng': -90.5092093802915}}}, 'place_id': 'ChIJAQA0IxWiiYUREnFzeK0cB60', 'plus_code': {'compound_code': 'JFPR+RV Guatemala City, Guatemala', 'global_code': '766FJFPR+RV'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Concepción Chiquirichapa', [{'address_components': [{'long_name': 'Concepción Chiquirichapa', 'short_name': 'Concepción Chiquirichapa', 'types': ['locality', 'political']}, {'long_name': 'Quetzaltenango Department', 'short_name': 'Quetzaltenango Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'geometry': {'location': {'lat': 14.8552026, 'lng': -91.6239444}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.8565515802915, 'lng': -91.6225954197085}, 'southwest': {'lat': 14.8538536197085, 'lng': -91.62529338029151}}}, 'place_id': 'ChIJ2d-Tkm6ajoURIgoOnYhDdw8', 'plus_code': {'compound_code': 'V94G+3C Concepción Chiquirichapa, Guatemala', 'global_code': '766CV94G+3C'}, 'types': ['courthouse', 'establishment', 'local_government_office', 'point_of_interest']}])
# ('Bolsa de Trabajo', [{'address_components': [{'long_name': '5 Avenida', 'short_name': '5 Avenida', 'types': ['route']}, {'long_name': 'Zona 14', 'short_name': 'Zona 14', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'geometry': {'location': {'lat': 14.5877888, 'lng': -90.514001}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.5891377802915, 'lng': -90.5126520197085}, 'southwest': {'lat': 14.5864398197085, 'lng': -90.5153499802915}}}, 'place_id': 'ChIJUWQd0umjiYURElsMWwaZAK4', 'plus_code': {'compound_code': 'HFQP+49 Guatemala City, Guatemala', 'global_code': '766FHFQP+49'}, 'types': ['establishment', 'point_of_interest']}, {'address_components': [{'long_name': '24-69', 'short_name': '24-69', 'types': ['street_number']}, {'long_name': 'Interamerican Highway', 'short_name': 'Interamerican Hwy', 'types': ['route']}, {'long_name': 'Zona 10', 'short_name': 'Zona 10', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'geometry': {'location': {'lat': 14.5816055, 'lng': -90.4954818}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 14.5829544802915, 'lng': -90.4941328197085}, 'southwest': {'lat': 14.5802565197085, 'lng': -90.4968307802915}}}, 'place_id': 'ChIJoWavMZqjiYURPZD51ANwaRo', 'plus_code': {'compound_code': 'HGJ3+JR Guatemala City, Guatemala', 'global_code': '766FHGJ3+JR'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Retalhuleu', [{'address_components': [{'long_name': 'Retalhuleu', 'short_name': 'Retalhuleu', 'types': ['locality', 'political']}, {'long_name': 'Retalhuleu Department', 'short_name': 'Retalhuleu Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Retalhuleu, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.555921, 'lng': -91.661768}, 'southwest': {'lat': 14.5086458, 'lng': -91.7044258}}, 'location': {'lat': 14.5245485, 'lng': -91.685788}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.555921, 'lng': -91.661768}, 'southwest': {'lat': 14.5086458, 'lng': -91.7044258}}}, 'place_id': 'ChIJqT9yNdzxjoUR7fzc6QkWmZY', 'types': ['locality', 'political']}])
# ('Delegación Guatemala', [{'address_components': [{'long_name': 'Antigua Guatemala', 'short_name': 'Antigua Guatemala', 'types': ['locality', 'political']}, {'long_name': 'Sacatepéquez Department', 'short_name': 'Sacatepéquez Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Antigua Guatemala, Guatemala', 'geometry': {'location': {'lat': 14.5695774, 'lng': -90.74085830000001}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.5709263802915, 'lng': -90.73950931970852}, 'southwest': {'lat': 14.5682284197085, 'lng': -90.74220728029152}}}, 'place_id': 'ChIJQVDUwOMNiYURst2VeDpASgQ', 'plus_code': {'compound_code': 'H795+RM Antigua Guatemala, Guatemala', 'global_code': '766FH795+RM'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Mazatenango', [{'address_components': [{'long_name': 'CA2', 'short_name': 'CA2', 'types': ['route']}, {'long_name': 'Mazatenango', 'short_name': 'Mazatenango', 'types': ['locality', 'political']}, {'long_name': 'Suchitepéquez', 'short_name': 'Suchitepéquez', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'CA2, Mazatenango, Guatemala', 'geometry': {'location': {'lat': 14.5323093, 'lng': -91.51466219999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.5336582802915, 'lng': -91.51331321970848}, 'southwest': {'lat': 14.5309603197085, 'lng': -91.5160111802915}}}, 'place_id': 'ChIJa8Z_8XPCjoURM2j4Get2dfI', 'plus_code': {'compound_code': 'GFJP+W4 Mazatenango, Guatemala', 'global_code': '766CGFJP+W4'}, 'types': ['establishment', 'local_government_office', 'point_of_interest']}])
# ('Delegación El Estor', [{'address_components': [{'long_name': 'El Estor', 'short_name': 'El Estor', 'types': ['locality', 'political']}, {'long_name': 'Izabal Department', 'short_name': 'Izabal Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'El Estor, Guatemala', 'geometry': {'location': {'lat': 15.5230375, 'lng': -89.33432379999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.5243864802915, 'lng': -89.33297481970848}, 'southwest': {'lat': 15.5216885197085, 'lng': -89.3356727802915}}}, 'place_id': 'ChIJBS9dfzgJYY8RlTSfRkV0Aac', 'plus_code': {'compound_code': 'GMF8+67 El Estor, Guatemala', 'global_code': '767GGMF8+67'}, 'types': ['establishment', 'local_government_office', 'point_of_interest']}])
# ('Delegación Serchil', [{'address_components': [{'long_name': 'RN-12N', 'short_name': 'RN-12N', 'types': ['route']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['locality', 'political']}, {'long_name': 'San Marcos', 'short_name': 'San Marcos', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'RN-12N, Guatemala', 'geometry': {'location': {'lat': 15.0469738, 'lng': -91.81141919999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.0483227802915, 'lng': -91.81007021970848}, 'southwest': {'lat': 15.0456248197085, 'lng': -91.81276818029149}}}, 'place_id': 'ChIJHUzqc5UrjIURpH_watAfoLU', 'plus_code': {'compound_code': '25WQ+QC San Sebastián, Guatemala', 'global_code': '767C25WQ+QC'}, 'types': ['doctor', 'establishment', 'health', 'point_of_interest']}])
# ('Delegación Quetzaltenango', [{'address_components': [{'long_name': 'Quetzaltenango Department', 'short_name': 'Quetzaltenango Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Quetzaltenango Department, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 15.2086839, 'lng': -91.418515}, 'southwest': {'lat': 14.5093989, 'lng': -92.144752}}, 'location': {'lat': 14.792433, 'lng': -91.714958}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 15.2086839, 'lng': -91.418515}, 'southwest': {'lat': 14.5093989, 'lng': -92.144752}}}, 'place_id': 'ChIJMax-PBWGjoURA28YmtA00Sk', 'types': ['administrative_area_level_1', 'political']}])
# ('Delegación Cobán', [{'address_components': [{'long_name': 'Cobán', 'short_name': 'Cobán', 'types': ['locality', 'political']}, {'long_name': 'Zona 4', 'short_name': 'Zona 4', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Alta Verapaz Department', 'short_name': 'Alta Verapaz Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Cobán, Guatemala', 'geometry': {'location': {'lat': 15.4755295, 'lng': -90.3711829}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.4768784802915, 'lng': -90.3698339197085}, 'southwest': {'lat': 15.4741805197085, 'lng': -90.3725318802915}}}, 'place_id': 'ChIJca0D6zVBioUR9epUAjr5kx4', 'plus_code': {'compound_code': 'FJGH+6G Cobán, Guatemala', 'global_code': '767FFJGH+6G'}, 'types': ['establishment', 'local_government_office', 'point_of_interest']}])
# ('País', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 17.815697, 'lng': -88.1982001}, 'southwest': {'lat': 13.63, 'lng': -92.2714}}, 'location': {'lat': 15.783471, 'lng': -90.23075899999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 17.815697, 'lng': -88.1982001}, 'southwest': {'lat': 13.63, 'lng': -92.2714}}}, 'place_id': 'ChIJa1DnNlATiIURu9WEWzcrmDU', 'types': ['country', 'political']}])
# ('Delegación Quiché', [{'address_components': [{'long_name': 'Quiché Department', 'short_name': 'Quiché Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Quiché Department, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 16.0730049, 'lng': -90.412424}, 'southwest': {'lat': 14.7989009, 'lng': -91.3238779}}, 'location': {'lat': 15.4983808, 'lng': -90.9820668}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 16.0730049, 'lng': -90.412424}, 'southwest': {'lat': 14.7989009, 'lng': -91.3238779}}}, 'place_id': 'ChIJPW_nQ0hiiYURBjITZlp4umQ', 'types': ['administrative_area_level_1', 'political']}])
# ('Juventud', [{'address_components': [{'long_name': 'Cobán', 'short_name': 'Cobán', 'types': ['locality', 'political']}, {'long_name': 'Zona 4', 'short_name': 'Zona 4', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Alta Verapaz Department', 'short_name': 'Alta Verapaz Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Cobán, Guatemala', 'geometry': {'location': {'lat': 15.4712267, 'lng': -90.3670167}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.4725756802915, 'lng': -90.36566771970848}, 'southwest': {'lat': 15.4698777197085, 'lng': -90.3683656802915}}}, 'partial_match': True, 'place_id': 'ChIJm-zJMzdBioURV2Wxe2qc1XM', 'plus_code': {'compound_code': 'FJCM+F5 Cobán, Guatemala', 'global_code': '767FFJCM+F5'}, 'types': ['establishment', 'point_of_interest', 'school']}])
# ('Teléfonos 24/7', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'geometry': {'location': {'lat': 14.593292, 'lng': -90.54209499999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.5946409802915, 'lng': -90.5407460197085}, 'southwest': {'lat': 14.5919430197085, 'lng': -90.5434439802915}}}, 'place_id': 'ChIJdTa0nGuhiYUR9DuRzpRF_CM', 'plus_code': {'compound_code': 'HFV5+85 Guatemala City, Guatemala', 'global_code': '766FHFV5+85'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Purulha', [{'address_components': [{'long_name': 'Purulha', 'short_name': 'Purulha', 'types': ['locality', 'political']}, {'long_name': 'Baja Verapaz Department', 'short_name': 'Baja Verapaz Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Purulha, Guatemala', 'geometry': {'location': {'lat': 15.2329402, 'lng': -90.2342584}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 15.2342891802915, 'lng': -90.2329094197085}, 'southwest': {'lat': 15.2315912197085, 'lng': -90.23560738029151}}}, 'place_id': 'ChIJnTYwZEUXioUR1jlleWOZKIQ', 'plus_code': {'compound_code': '6QM8+57 Purulha, Guatemala', 'global_code': '767F6QM8+57'}, 'types': ['establishment', 'health', 'point_of_interest']}])
# ('Acceso a la Información', [{'address_components': [{'long_name': 'Prolongacion Ave Alberto Masferrer', 'short_name': 'Prolongacion Ave Alberto Masferrer', 'types': ['route']}, {'long_name': 'San Salvador', 'short_name': 'San Salvador', 'types': ['locality', 'political']}, {'long_name': 'El Salvador', 'short_name': 'SV', 'types': ['country', 'political']}], 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'geometry': {'location': {'lat': 13.7221171, 'lng': -89.23568310000002}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 13.7234660802915, 'lng': -89.23433411970852}, 'southwest': {'lat': 13.7207681197085, 'lng': -89.23703208029153}}}, 'place_id': 'ChIJNRekNA8wY48RtAZeiGvY22Y', 'plus_code': {'compound_code': 'PQC7+RP San Salvador, El Salvador', 'global_code': '765GPQC7+RP'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Santo Tomás de Castilla', [{'address_components': [{'long_name': 'Santo Tomás de Castilla', 'short_name': 'Santo Tomás de Castilla', 'types': ['locality', 'political']}, {'long_name': 'Izabal Department', 'short_name': 'Izabal Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'geometry': {'location': {'lat': 15.69018, 'lng': -88.620407}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 15.7009219, 'lng': -88.6043996}, 'southwest': {'lat': 15.6794375, 'lng': -88.63641439999999}}}, 'partial_match': True, 'place_id': 'ChIJJVy9SfHZZo8RHV6WIFmDSrY', 'types': ['locality', 'political']}])
# ('Ciudad', [{'address_components': [{'long_name': 'Guatemala City', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala Department', 'short_name': 'Guatemala Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Guatemala City, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.7012545, 'lng': -90.39645209999999}, 'southwest': {'lat': 14.5511856, 'lng': -90.5886688}}, 'location': {'lat': 14.6349149, 'lng': -90.5068824}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.7012545, 'lng': -90.39645209999999}, 'southwest': {'lat': 14.5511856, 'lng': -90.5886688}}}, 'place_id': 'ChIJRTNcZYChiYURJXuGW4HHcko', 'types': ['locality', 'political']}, {'address_components': [{'long_name': 'Ciudad Vieja', 'short_name': 'Ciudad Vieja', 'types': ['locality', 'political']}, {'long_name': 'Sacatepéquez Department', 'short_name': 'Sacatepéquez Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Ciudad Vieja, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.5318277, 'lng': -90.74646949999999}, 'southwest': {'lat': 14.515044, 'lng': -90.78277589999999}}, 'location': {'lat': 14.5264336, 'lng': -90.76041099999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.5318277, 'lng': -90.74646949999999}, 'southwest': {'lat': 14.515044, 'lng': -90.78277589999999}}}, 'place_id': 'ChIJoXugLDMQiYUR8aSxMRgCHzA', 'types': ['locality', 'political']}, {'address_components': [{'long_name': 'Ciudad Jardín Lantana', 'short_name': 'Ciudad Jardín Lantana', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Ciudad Jardín Lantana, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 14.714798, 'lng': -90.6141507}, 'southwest': {'lat': 14.7100763, 'lng': -90.62026619999999}}, 'location': {'lat': 14.7126329, 'lng': -90.6174558}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 14.714798, 'lng': -90.6141507}, 'southwest': {'lat': 14.7100763, 'lng': -90.62026619999999}}}, 'place_id': 'ChIJH_B2EZl1iYUR49SEJBE2iY8', 'types': ['locality', 'political']}, {'address_components': [{'long_name': '6th', 'short_name': '6th', 'types': ['route']}, {'long_name': 'Ciudad de Manila', 'short_name': 'Cd de Manila', 'types': ['locality', 'political']}, {'long_name': 'Gran Manila', 'short_name': 'NCR', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Philippines', 'short_name': 'PH', 'types': ['country', 'political']}], 'formatted_address': '0 calle zona, 6th, Cd de Manila, Philippines', 'geometry': {'location': {'lat': 14.849265, 'lng': -91.54679800000001}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.8506139802915, 'lng': -91.54544901970851}, 'southwest': {'lat': 14.8479160197085, 'lng': -91.54814698029152}}}, 'place_id': 'ChIJi3YO9ySYjoURS1keVB4N3A0', 'plus_code': {'compound_code': 'RFX3+P7 Quetzaltenango, Guatemala', 'global_code': '766CRFX3+P7'}, 'types': ['colloquial_area', 'establishment', 'locality', 'point_of_interest', 'political']}, {'address_components': [{'long_name': 'Ciudad Cuauhtémoc', 'short_name': 'Ciudad Cuauhtémoc', 'types': ['locality', 'political']}, {'long_name': 'Chiapas', 'short_name': 'Chis.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}], 'formatted_address': 'Ciudad Cuauhtémoc, Chis., Mexico', 'geometry': {'bounds': {'northeast': {'lat': 15.6722001, 'lng': -91.9978321}, 'southwest': {'lat': 15.6619621, 'lng': -92.00823799999999}}, 'location': {'lat': 15.6658629, 'lng': -92.0040 ...
# ('Roja', [{'address_components': [{'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'geometry': {'location': {'lat': 14.6452757, 'lng': -90.5106878}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 14.6466246802915, 'lng': -90.50933881970849}, 'southwest': {'lat': 14.6439267197085, 'lng': -90.5120367802915}}}, 'place_id': 'ChIJW54vPBKiiYUR-EtI2ZCPUO4', 'plus_code': {'compound_code': 'JFWQ+4P Guatemala City, Guatemala', 'global_code': '766FJFWQ+4P'}, 'types': ['establishment', 'point_of_interest']}])
# ('Federación Internacional de la Cruz Roja', [{'address_components': [{'long_name': 'Colonia Guadalupe', 'short_name': 'Colonia Guadalupe', 'types': ['neighborhood', 'political']}, {'long_name': 'San Salvador', 'short_name': 'San Salvador', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'San Salvador', 'short_name': 'San Salvador', 'types': ['locality', 'political']}, {'long_name': 'San Salvador', 'short_name': 'San Salvador', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'San Salvador Department', 'short_name': 'San Salvador Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'El Salvador', 'short_name': 'SV', 'types': ['country', 'political']}], 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'geometry': {'location': {'lat': 13.7067774, 'lng': -89.1947117}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 13.7081263802915, 'lng': -89.19336271970849}, 'southwest': {'lat': 13.7054284197085, 'lng': -89.19606068029151}}}, 'place_id': 'ChIJs8cWXRAxY48RlDerxhkfWJw', 'plus_code': {'compound_code': 'PR44+P4 San Salvador, El Salvador', 'global_code': '765GPR44+P4'}, 'types': ['establishment', 'point_of_interest']}])
# ('Delegación Petén', [{'address_components': [{'long_name': 'Petén Department', 'short_name': 'Petén Department', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': 'Petén Department, Guatemala', 'geometry': {'bounds': {'northeast': {'lat': 17.8152201, 'lng': -89.14571409999999}, 'southwest': {'lat': 15.833072, 'lng': -91.437546}}, 'location': {'lat': 16.912033, 'lng': -90.2995785}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 17.8152201, 'lng': -89.14571409999999}, 'southwest': {'lat': 15.833072, 'lng': -91.437546}}}, 'place_id': 'ChIJYUHc3aVA9YURjUZ6_YSSEbk', 'types': ['administrative_area_level_1', 'political']}])

# %%
[(i[0],len(i[1])) for i in addresses_list_gt]
# Out:
# [('13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 2),
#  ('8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 1),
#  ('1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 2),
#  ('Casa #2 Colonia San Josecito Zona 1, Retalhuleu, Retalhuleu', 1),
#  ('0 Avenida 5 Calle Zona 2 Barrio el Rosario, Coatepeque, Quetzaltenango', 2),
#  ('9 Calle 5 Avenida Zona 1, El Estor, Izabal', 1),
#  ('6 Avenida 6 Calle "B" 6-36 Zona 1, El Palmar, Quetzaltenango', 2),
#  ('Calzada Revolución del 71 Zona 1, San Marcos, San Marcos', 1),
#  ('Barrio San Pedro Calle Principal frente al Puente Fray Bartolomé, Sacapulas, Quiché',
#   2),
#  ('Kilometro 164.5 Carretera a Cobán, Purulha, Baja Verapaz', 2),
#  ('3 Calle 2-13 Zona 3, Cobán, Alta Verapaz', 1),
#  ('Aldea San Antonio, Serchil, San Marcos', 1),
#  ('3 Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala', 1),
#  ('6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa', 1),
#  ('1 Avenida 3-51 Zona 1, Mazatenango, Suchitepequez', 1),
#  ('3 Avenida Zona 1 Barrio El Porvenir, San Benito, Petén', 1),
#  ('1 Avenida 3-51 Zona 1, Quetzaltenango, Quetzaltenango', 2),
#  ('4 Avenida 3-71 Zona 2, Tejutla, San Marcos', 2),
#  ('3 Calle Zona 2, Concepción Chiquirichapa, Quetzaltenango', 1),
#  ('Colonia Colina I 1 Calle atrás del Mercado Cantonal, Santo Tomás de Castilla, Izabal',
#   1),
#  ('3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.', 1),
#  ('9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula',
#   2)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
vectorizer.fit([name[0] for name in name_list_gt])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
def plot(string):
    df=pd.DataFrame([vectorizer.get_feature_names(),vectorizer.transform([string]).todense()[0].tolist()[0]]).T.sort_values(1,ascending=False)
    df=df[df[1]==df[1].max()]
    df.columns=['topic','score']
    df['name']=string
    return df[0:1]
pd.concat(list(map(lambda x: plot(x),[name[0] for name in name_list_gt])))
# Out:
#                     topic     score                                       name
# 44         delegación san  0.490702                      Delegación San Marcos
# 30  delegación chiquimula  0.681515                      Delegación Chiquimula
# 20       contactenos cruz  0.438195       Contactenos | Cruz Roja Guatemalteca
# 51              el palmar  0.516045                       Delegación El Palmar
# 84           sede central   0.57735                               Sede Central
# 36      delegación jalapa  0.681515                          Delegación Jalapa
# 23                   cruz         1                                      #Cruz
# 43   delegación sacapulas  0.681515                       Delegación Sacapulas
# 47       delegación tecún  0.490702                      Delegación Tecún Umán
# 0                    2015  0.372473  Copyright © 2015 - Cruz Roja Guatemalteca
# 68        nombre completo   0.57735                            Nombre Completo
# 48     delegación tejutla  0.681515                         Delegación Tejutla
# 12             coatepeque  0.681515                      Delegación Coatepeque
# 14                 comité  0.352124       Comité Internacional de la Cruz Roja
# 33  delegación concepción  0.490702        Delegación Concepción Chiquirichapa
# 93                trabajo  0.467178                           Bolsa de Trabajo
# 75             retalhuleu  0.681515                      Delegación Retalhuleu
# 35   delegación guatemala  0.681515                       Delegación Guatemala
# 66            mazatenango  0.681515                     Delegación Mazatenango
# 50               el estor  0.516045                        Delegación El Estor
# 46     delegación serchil  0.681515                         Delegación Serchil
# 73         quetzaltenango  0.681515                  Delegación Quetzaltenango
# 13                  cobán  0.681515                           Delegación Cobán
# 70                   país         1                                       País
# 74                 quiché  0.681515                          Delegación Quiché
# 61               juventud         1                                   Juventud
# 2                      24   0.57735                             Teléfonos 24/7
# 72                purulha  0.681515                         Delegación Purulha
# 3                  acceso  0.462583                    Acceso a la Información
# 82            santo tomás  0.359563         Delegación Santo Tomás de Castilla
# 11                 ciudad         1                                     Ciudad
# 76                   roja         1                                       Roja
# 53             federación  0.352124   Federación Internacional de la Cruz Roja
# 71                  petén  0.681515                           Delegación Petén

# %%
from fuzzywuzzy import fuzz
import collections
import math

def weight_name(name_a,name_b):
    df=pd.DataFrame([vectorizer.get_feature_names(),vectorizer.transform([name_b]).todense()[0].tolist()[0]]).T.sort_values(1,ascending=False)
    df=df[df[1]==df[1].max()]
    df.columns=['topic','score']
    #print(df['topic'].tolist())
    dup_ind=1/math.exp(sum([name_a.lower().count(i)*len(i.split(' ')) for i in df['topic'].tolist()]))
    similar_ind=1/(1+fuzz.ratio(name_a,name_b))
    print(dup_ind,similar_ind)
    return dup_ind*similar_ind

# %%
min_distance_list=[]
for addresses in addresses_list_gt:
    address_name=addresses[0]
    for names in name_list_gt:
        department_name=names[0]
        if len(names[1])>3:
            continue
#         if not validate_place_name(department_name):
#             continue
        #print(address_name,department_name)
        min_dis=999999
        #print(min_dis)
        for add_rep in addresses[1]:
            #print(add_rep)
            address_dict=parse_response(add_rep,address_name)
            for name_rep in names[1]:
                
                name_dict=parse_response(name_rep,department_name)
                print(address_dict,name_dict)
                dist=calculate_distance((address_dict['lat'],address_dict['lng']),(name_dict['lat'],name_dict['lng']))
                #print(dist)
                if dist<min_dis:
                    min_dis=dist*weight_name(address_name,department_name)
        min_distance_list.append({"web_lat":address_dict['lat'],"web_lng":address_dict['lng'],"address":address_name,"name":department_name,"min_dist":min_dis,"weight":weight_name(address_name,department_name)})
# Out:
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos, Guatemala', 'lat': 14.9609782, 'lng': -91.80745859999999}
# 0.36787944117144233 0.041666666666666664
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos Department, Guatemala', 'lat': 14.9309569, 'lng': -91.9099238}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos, Guatemala', 'lat': 14.9609782, 'lng': -91.80745859999999}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos Department, Guatemala', 'lat': 14.9309569, 'lng': -91.9099238}
# 0.36787944117144233 0.041666666666666664
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.7924897, 'lng': -89.5450458}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.7924897, 'lng': -89.5450458}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Contactenos | Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.034482758620689655
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Contactenos | Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.034482758620689655
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación El Palmar', 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'lat': 14.6479532, 'lng': -91.5568436}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación El Palmar', 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'lat': 14.6479532, 'lng': -91.5568436}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Sede Central', 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'lat': 14.6353845, 'lng': -90.50777939999999}
# 1.0 0.05263157894736842
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Sede Central', 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'lat': 14.6353845, 'lng': -90.50777939999999}
# 1.0 0.05263157894736842
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Jalapa', 'formatted_address': 'Jalapa, Guatemala', 'lat': 14.6325483, 'lng': -89.9930052}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Jalapa', 'formatted_address': 'Jalapa, Guatemala', 'lat': 14.6325483, 'lng': -89.9930052}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': '#Cruz', 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'lat': 15.469403, 'lng': -90.3718126}
# 0.36787944117144233 0.08333333333333333
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': '#Cruz', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4706183, 'lng': -90.3721394}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': '#Cruz', 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'lat': 15.469403, 'lng': -90.3718126}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': '#Cruz', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4706183, 'lng': -90.3721394}
# 0.36787944117144233 0.08333333333333333
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Sacapulas', 'formatted_address': 'Sacapulas, Guatemala', 'lat': 15.2895072, 'lng': -91.0891163}
# 1.0 0.045454545454545456
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Sacapulas', 'formatted_address': 'Sacapulas, Guatemala', 'lat': 15.2895072, 'lng': -91.0891163}
# 1.0 0.045454545454545456
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Tecún Umán', 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'lat': 14.6777526, 'lng': -92.1418964}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Tecún Umán', 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'lat': 14.6777526, 'lng': -92.1418964}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Copyright © 2015 - Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.041666666666666664
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Copyright © 2015 - Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.041666666666666664
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Nombre Completo', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Nombre Completo', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.058823529411764705
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.058823529411764705
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.03225806451612903
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.03225806451612903
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.04
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.04
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Retalhuleu', 'formatted_address': 'Retalhuleu, Guatemala', 'lat': 14.5245485, 'lng': -91.685788}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Retalhuleu', 'formatted_address': 'Retalhuleu, Guatemala', 'lat': 14.5245485, 'lng': -91.685788}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Guatemala', 'formatted_address': 'Antigua Guatemala, Guatemala', 'lat': 14.5695774, 'lng': -90.74085830000001}
# 1.0 0.1
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Guatemala', 'formatted_address': 'Antigua Guatemala, Guatemala', 'lat': 14.5695774, 'lng': -90.74085830000001}
# 1.0 0.1
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Mazatenango', 'formatted_address': 'CA2, Mazatenango, Guatemala', 'lat': 14.5323093, 'lng': -91.51466219999999}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Mazatenango', 'formatted_address': 'CA2, Mazatenango, Guatemala', 'lat': 14.5323093, 'lng': -91.51466219999999}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación El Estor', 'formatted_address': 'El Estor, Guatemala', 'lat': 15.5230375, 'lng': -89.33432379999999}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación El Estor', 'formatted_address': 'El Estor, Guatemala', 'lat': 15.5230375, 'lng': -89.33432379999999}
# 1.0 0.07692307692307693
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Serchil', 'formatted_address': 'RN-12N, Guatemala', 'lat': 15.0469738, 'lng': -91.81141919999999}
# 1.0 0.043478260869565216
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Serchil', 'formatted_address': 'RN-12N, Guatemala', 'lat': 15.0469738, 'lng': -91.81141919999999}
# 1.0 0.043478260869565216
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Quetzaltenango', 'formatted_address': 'Quetzaltenango Department, Guatemala', 'lat': 14.792433, 'lng': -91.714958}
# 1.0 0.07142857142857142
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Quetzaltenango', 'formatted_address': 'Quetzaltenango Department, Guatemala', 'lat': 14.792433, 'lng': -91.714958}
# 1.0 0.07142857142857142
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Cobán', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4755295, 'lng': -90.3711829}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Cobán', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4755295, 'lng': -90.3711829}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'País', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.25
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'País', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.25
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Quiché', 'formatted_address': 'Quiché Department, Guatemala', 'lat': 15.4983808, 'lng': -90.9820668}
# 0.1353352832366127 0.04
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Quiché', 'formatted_address': 'Quiché Department, Guatemala', 'lat': 15.4983808, 'lng': -90.9820668}
# 0.1353352832366127 0.04
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Juventud', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4712267, 'lng': -90.3670167}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Juventud', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4712267, 'lng': -90.3670167}
# 1.0 0.06666666666666667
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Teléfonos 24/7', 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'lat': 14.593292, 'lng': -90.54209499999999}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Teléfonos 24/7', 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'lat': 14.593292, 'lng': -90.54209499999999}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Purulha', 'formatted_address': 'Purulha, Guatemala', 'lat': 15.2329402, 'lng': -90.2342584}
# 1.0 0.05555555555555555
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Purulha', 'formatted_address': 'Purulha, Guatemala', 'lat': 15.2329402, 'lng': -90.2342584}
# 1.0 0.05555555555555555
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Acceso a la Información', 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'lat': 13.7221171, 'lng': -89.23568310000002}
# 1.0 0.047619047619047616
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Acceso a la Información', 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'lat': 13.7221171, 'lng': -89.23568310000002}
# 1.0 0.047619047619047616
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Santo Tomás de Castilla', 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'lat': 15.69018, 'lng': -88.620407}
# 1.0 0.037037037037037035
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Santo Tomás de Castilla', 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'lat': 15.69018, 'lng': -88.620407}
# 1.0 0.037037037037037035
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Roja', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.25
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Roja', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.25
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Federación Internacional de la Cruz Roja', 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'lat': 13.7067774, 'lng': -89.1947117}
# 1.0 0.03333333333333333
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Federación Internacional de la Cruz Roja', 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'lat': 13.7067774, 'lng': -89.1947117}
# 1.0 0.03333333333333333
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Zone 5, Guatemala City, Guatemala', 'lat': 14.6244193, 'lng': -90.4993588} {'query_name': 'Delegación Petén', 'formatted_address': 'Petén Department, Guatemala', 'lat': 16.912033, 'lng': -90.2995785}
# 1.0 0.09090909090909091
# {'query_name': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'formatted_address': 'Santa Cruz del Quiché, Guatemala', 'lat': 15.0248589, 'lng': -91.14727099999999} {'query_name': 'Delegación Petén', 'formatted_address': 'Petén Department, Guatemala', 'lat': 16.912033, 'lng': -90.2995785}
# 1.0 0.09090909090909091
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos, Guatemala', 'lat': 14.9609782, 'lng': -91.80745859999999}
# 1.0 0.08333333333333333
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos Department, Guatemala', 'lat': 14.9309569, 'lng': -91.9099238}
# 1.0 0.08333333333333333
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.7924897, 'lng': -89.5450458}
# 1.0 0.04
# 1.0 0.04
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Contactenos | Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.022727272727272728
# 1.0 0.022727272727272728
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación El Palmar', 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'lat': 14.6479532, 'lng': -91.5568436}
# 1.0 0.08333333333333333
# 1.0 0.08333333333333333
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Sede Central', 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'lat': 14.6353845, 'lng': -90.50777939999999}
# 1.0 0.043478260869565216
# 1.0 0.043478260869565216
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Jalapa', 'formatted_address': 'Jalapa, Guatemala', 'lat': 14.6325483, 'lng': -89.9930052}
# 1.0 0.06666666666666667
# 1.0 0.06666666666666667
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': '#Cruz', 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'lat': 15.469403, 'lng': -90.3718126}
# 1.0 0.125
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': '#Cruz', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4706183, 'lng': -90.3721394}
# 1.0 0.125
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Sacapulas', 'formatted_address': 'Sacapulas, Guatemala', 'lat': 15.2895072, 'lng': -91.0891163}
# 1.0 0.058823529411764705
# 1.0 0.058823529411764705
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Tecún Umán', 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'lat': 14.6777526, 'lng': -92.1418964}
# 1.0 0.06666666666666667
# 1.0 0.06666666666666667
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Copyright © 2015 - Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.024390243902439025
# 1.0 0.024390243902439025
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Nombre Completo', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.0625
# 1.0 0.0625
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.05555555555555555
# 1.0 0.05555555555555555
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.04
# 1.0 0.04
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.02702702702702703
# 1.0 0.02702702702702703
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.047619047619047616
# 1.0 0.047619047619047616
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# 1.0 0.047619047619047616
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# 1.0 0.047619047619047616
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Retalhuleu', 'formatted_address': 'Retalhuleu, Guatemala', 'lat': 14.5245485, 'lng': -91.685788}
# 1.0 0.05
# 1.0 0.05
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Guatemala', 'formatted_address': 'Antigua Guatemala, Guatemala', 'lat': 14.5695774, 'lng': -90.74085830000001}
# 0.1353352832366127 0.029411764705882353
# 0.1353352832366127 0.029411764705882353
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Mazatenango', 'formatted_address': 'CA2, Mazatenango, Guatemala', 'lat': 14.5323093, 'lng': -91.51466219999999}
# 1.0 0.058823529411764705
# 1.0 0.058823529411764705
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación El Estor', 'formatted_address': 'El Estor, Guatemala', 'lat': 15.5230375, 'lng': -89.33432379999999}
# 1.0 0.1111111111111111
# 1.0 0.1111111111111111
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Serchil', 'formatted_address': 'RN-12N, Guatemala', 'lat': 15.0469738, 'lng': -91.81141919999999}
# 1.0 0.08333333333333333
# 1.0 0.08333333333333333
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Quetzaltenango', 'formatted_address': 'Quetzaltenango Department, Guatemala', 'lat': 14.792433, 'lng': -91.714958}
# 1.0 0.07142857142857142
# 1.0 0.07142857142857142
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Cobán', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4755295, 'lng': -90.3711829}
# 1.0 0.07692307692307693
# 1.0 0.07692307692307693
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'País', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.2
# 1.0 0.2
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Quiché', 'formatted_address': 'Quiché Department, Guatemala', 'lat': 15.4983808, 'lng': -90.9820668}
# 1.0 0.14285714285714285
# 1.0 0.14285714285714285
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Juventud', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4712267, 'lng': -90.3670167}
# 1.0 0.058823529411764705
# 1.0 0.058823529411764705
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Teléfonos 24/7', 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'lat': 14.593292, 'lng': -90.54209499999999}
# 1.0 0.07692307692307693
# 1.0 0.07692307692307693
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Purulha', 'formatted_address': 'Purulha, Guatemala', 'lat': 15.2329402, 'lng': -90.2342584}
# 1.0 0.14285714285714285
# 1.0 0.14285714285714285
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Acceso a la Información', 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'lat': 13.7221171, 'lng': -89.23568310000002}
# 1.0 0.05263157894736842
# 1.0 0.05263157894736842
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Santo Tomás de Castilla', 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'lat': 15.69018, 'lng': -88.620407}
# 1.0 0.034482758620689655
# 1.0 0.034482758620689655
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Roja', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.2
# 1.0 0.2
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Federación Internacional de la Cruz Roja', 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'lat': 13.7067774, 'lng': -89.1947117}
# 1.0 0.02857142857142857
# 1.0 0.02857142857142857
# {'query_name': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'formatted_address': '8A Av 3, Guatemala', 'lat': 14.6506904, 'lng': -90.51013080000001} {'query_name': 'Delegación Petén', 'formatted_address': 'Petén Department, Guatemala', 'lat': 16.912033, 'lng': -90.2995785}
# 1.0 0.1
# 1.0 0.1
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos, Guatemala', 'lat': 14.9609782, 'lng': -91.80745859999999}
# 0.018315638888734182 0.025
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos Department, Guatemala', 'lat': 14.9309569, 'lng': -91.9099238}
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos, Guatemala', 'lat': 14.9609782, 'lng': -91.80745859999999}
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación San Marcos', 'formatted_address': 'San Marcos Department, Guatemala', 'lat': 14.9309569, 'lng': -91.9099238}
# 0.018315638888734182 0.025
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.7924897, 'lng': -89.5450458}
# 1.0 0.05263157894736842
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.7924897, 'lng': -89.5450458}
# 1.0 0.05263157894736842
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Contactenos | Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.047619047619047616
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Contactenos | Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.047619047619047616
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación El Palmar', 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'lat': 14.6479532, 'lng': -91.5568436}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación El Palmar', 'formatted_address': 'El Palmar, Quetzaltenango, Guatemala', 'lat': 14.6479532, 'lng': -91.5568436}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Sede Central', 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'lat': 14.6353845, 'lng': -90.50777939999999}
# 1.0 0.06666666666666667
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Sede Central', 'formatted_address': '12 Avenida 12-54, Guatemala 01001, Guatemala', 'lat': 14.6353845, 'lng': -90.50777939999999}
# 1.0 0.06666666666666667
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Jalapa', 'formatted_address': 'Jalapa, Guatemala', 'lat': 14.6325483, 'lng': -89.9930052}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Jalapa', 'formatted_address': 'Jalapa, Guatemala', 'lat': 14.6325483, 'lng': -89.9930052}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': '#Cruz', 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'lat': 15.469403, 'lng': -90.3718126}
# 1.0 0.2
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': '#Cruz', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4706183, 'lng': -90.3721394}
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': '#Cruz', 'formatted_address': '2-13, 2a Calle, Cobán, Guatemala', 'lat': 15.469403, 'lng': -90.3718126}
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': '#Cruz', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4706183, 'lng': -90.3721394}
# 1.0 0.2
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Sacapulas', 'formatted_address': 'Sacapulas, Guatemala', 'lat': 15.2895072, 'lng': -91.0891163}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Sacapulas', 'formatted_address': 'Sacapulas, Guatemala', 'lat': 15.2895072, 'lng': -91.0891163}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Tecún Umán', 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'lat': 14.6777526, 'lng': -92.1418964}
# 0.018315638888734182 0.025
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Tecún Umán', 'formatted_address': 'Ciudad Tecun Uman, Guatemala', 'lat': 14.6777526, 'lng': -92.1418964}
# 0.018315638888734182 0.025
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Copyright © 2015 - Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Copyright © 2015 - Cruz Roja Guatemalteca', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Nombre Completo', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.09090909090909091
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Nombre Completo', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.09090909090909091
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.05
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.0625
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.0625
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.03225806451612903
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.03225806451612903
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': 'Ayutla, Guatemala', 'lat': 14.68003, 'lng': -92.132172} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.043478260869565216
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# 1.0 0.041666666666666664
# {'query_name': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'formatted_address': '1 Avenida 4, Guatemala', 'lat': 14.6029046, 'lng': -90.5148114} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# ...
# 1.0 0.038461538461538464
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Tejutla', 'formatted_address': 'Avenida 3-71 4, Tejutla, Guatemala', 'lat': 15.1209353, 'lng': -91.80667799999999}
# 1.0 0.038461538461538464
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Coatepeque', 'formatted_address': 'Unnamed Road, Coatepeque, Guatemala', 'lat': 14.707494, 'lng': -91.86847780000001}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.034482758620689655
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Comité Internacional de la Cruz Roja', 'formatted_address': '11 Calle 11-28, Guatemala', 'lat': 14.6371215, 'lng': -90.5078604}
# 1.0 0.034482758620689655
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.02702702702702703
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Concepción Chiquirichapa', 'formatted_address': 'Concepción Chiquirichapa, Guatemala', 'lat': 14.8552026, 'lng': -91.6239444}
# 1.0 0.02702702702702703
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# 1.0 0.07142857142857142
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': '5ta. Avenida 5-55 zona 14, Europlaza. Torre 4, 6to nivel, oficina 602, 5 Avenida, Guatemala', 'lat': 14.5877888, 'lng': -90.514001}
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Bolsa de Trabajo', 'formatted_address': 'Interamerican Hwy 24-69, Guatemala', 'lat': 14.5816055, 'lng': -90.4954818}
# 1.0 0.07142857142857142
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Retalhuleu', 'formatted_address': 'Retalhuleu, Guatemala', 'lat': 14.5245485, 'lng': -91.685788}
# 1.0 0.029411764705882353
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Retalhuleu', 'formatted_address': 'Retalhuleu, Guatemala', 'lat': 14.5245485, 'lng': -91.685788}
# 1.0 0.029411764705882353
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Guatemala', 'formatted_address': 'Antigua Guatemala, Guatemala', 'lat': 14.5695774, 'lng': -90.74085830000001}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Guatemala', 'formatted_address': 'Antigua Guatemala, Guatemala', 'lat': 14.5695774, 'lng': -90.74085830000001}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Mazatenango', 'formatted_address': 'CA2, Mazatenango, Guatemala', 'lat': 14.5323093, 'lng': -91.51466219999999}
# 1.0 0.034482758620689655
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Mazatenango', 'formatted_address': 'CA2, Mazatenango, Guatemala', 'lat': 14.5323093, 'lng': -91.51466219999999}
# 1.0 0.034482758620689655
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación El Estor', 'formatted_address': 'El Estor, Guatemala', 'lat': 15.5230375, 'lng': -89.33432379999999}
# 1.0 0.041666666666666664
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación El Estor', 'formatted_address': 'El Estor, Guatemala', 'lat': 15.5230375, 'lng': -89.33432379999999}
# 1.0 0.041666666666666664
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Serchil', 'formatted_address': 'RN-12N, Guatemala', 'lat': 15.0469738, 'lng': -91.81141919999999}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Serchil', 'formatted_address': 'RN-12N, Guatemala', 'lat': 15.0469738, 'lng': -91.81141919999999}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Quetzaltenango', 'formatted_address': 'Quetzaltenango Department, Guatemala', 'lat': 14.792433, 'lng': -91.714958}
# 1.0 0.03333333333333333
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Quetzaltenango', 'formatted_address': 'Quetzaltenango Department, Guatemala', 'lat': 14.792433, 'lng': -91.714958}
# 1.0 0.03333333333333333
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Cobán', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4755295, 'lng': -90.3711829}
# 1.0 0.05
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Cobán', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4755295, 'lng': -90.3711829}
# 1.0 0.05
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'País', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.16666666666666666
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'País', 'formatted_address': 'Guatemala', 'lat': 15.783471, 'lng': -90.23075899999999}
# 1.0 0.16666666666666666
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Quiché', 'formatted_address': 'Quiché Department, Guatemala', 'lat': 15.4983808, 'lng': -90.9820668}
# 1.0 0.041666666666666664
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Quiché', 'formatted_address': 'Quiché Department, Guatemala', 'lat': 15.4983808, 'lng': -90.9820668}
# 1.0 0.041666666666666664
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Juventud', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4712267, 'lng': -90.3670167}
# 1.0 0.1
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Juventud', 'formatted_address': 'Cobán, Guatemala', 'lat': 15.4712267, 'lng': -90.3670167}
# 1.0 0.1
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Teléfonos 24/7', 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'lat': 14.593292, 'lng': -90.54209499999999}
# 1.0 0.125
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Teléfonos 24/7', 'formatted_address': 'Complejo Empresarial Cortijo II, Bodega 121, Calz. Atanasio Tzul 22-00,, Zona 12, Guatemala', 'lat': 14.593292, 'lng': -90.54209499999999}
# 1.0 0.125
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Purulha', 'formatted_address': 'Purulha, Guatemala', 'lat': 15.2329402, 'lng': -90.2342584}
# 1.0 0.038461538461538464
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Purulha', 'formatted_address': 'Purulha, Guatemala', 'lat': 15.2329402, 'lng': -90.2342584}
# 1.0 0.038461538461538464
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Acceso a la Información', 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'lat': 13.7221171, 'lng': -89.23568310000002}
# 1.0 0.05263157894736842
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Acceso a la Información', 'formatted_address': 'No. 88, Col. San Antonio Abad. Calle al Volcán., Prolongacion Ave Alberto Masferrer, San Salvador, El Salvador', 'lat': 13.7221171, 'lng': -89.23568310000002}
# 1.0 0.05263157894736842
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Santo Tomás de Castilla', 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'lat': 15.69018, 'lng': -88.620407}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Santo Tomás de Castilla', 'formatted_address': 'Santo Tomás de Castilla, Guatemala', 'lat': 15.69018, 'lng': -88.620407}
# 1.0 0.03571428571428571
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Roja', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.3333333333333333
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Roja', 'formatted_address': '3ra Calle 8-40 01001 Guatemala, Guatemala', 'lat': 14.6452757, 'lng': -90.5106878}
# 1.0 0.3333333333333333
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Federación Internacional de la Cruz Roja', 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'lat': 13.7067774, 'lng': -89.1947117}
# 1.0 0.03125
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Federación Internacional de la Cruz Roja', 'formatted_address': 'Colonia Guadalupe, San Salvador, El Salvador', 'lat': 13.7067774, 'lng': -89.1947117}
# 1.0 0.03125
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': '9 Calle A, Guatemala', 'lat': 14.6557245, 'lng': -90.49828529999999} {'query_name': 'Delegación Petén', 'formatted_address': 'Petén Department, Guatemala', 'lat': 16.912033, 'lng': -90.2995785}
# 1.0 0.04
# {'query_name': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'formatted_address': 'Chiquimula, Guatemala', 'lat': 14.8023174, 'lng': -89.54185199999999} {'query_name': 'Delegación Petén', 'formatted_address': 'Petén Department, Guatemala', 'lat': 16.912033, 'lng': -90.2995785}
# 1.0 0.04

# %%
min_dist_df_gt=pd.DataFrame(min_distance_list)

# %%
matched_list=[]
for row in min_dist_df_gt.sort_values("min_dist",ascending=True).iterrows():
    row_=row[1]
    flag=0
    if len([i for i in matched_list if row_['name'] in i['name']]):
        continue
    for previous in matched_list:
#         if row_['name'] in previous['name']:
#                 continue
        if previous['address']==row_['address']:
            
            flag=1
            if previous['min_dist']==row_["min_dist"]:
                previous['name'].add(row_['name'])
    if flag==0:
        tmp_dict=row_.to_dict()
        tmp_dict['name']=set([tmp_dict['name']])
        print(tmp_dict)
        matched_list.append(tmp_dict)
# Out:
# {'address': '3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.', 'min_dist': 0.0, 'name': {'Copyright © 2015 - Cruz Roja Guatemalteca'}, 'web_lat': 14.6452757, 'web_lng': -90.5106878, 'weight': 0.030303030303030304}
# {'address': '3 Calle 2-13 Zona 3, Cobán, Alta Verapaz', 'min_dist': 0.0, 'name': {'#Cruz'}, 'web_lat': 15.469403, 'web_lng': -90.3718126, 'weight': 0.07142857142857142}
# {'address': 'Colonia Colina I 1 Calle atrás del Mercado Cantonal, Santo Tomás de Castilla, Izabal', 'min_dist': 1.6784843096003715e-06, 'name': {'Delegación Santo Tomás de Castilla'}, 'web_lat': 15.6852701, 'web_lng': -88.6165917, 'weight': 2.4681960817335907e-06}
# {'address': '9 Calle 5 Avenida Zona 1, El Estor, Izabal', 'min_dist': 0.0009719462011429664, 'name': {'Delegación El Estor'}, 'web_lat': 15.5245579, 'web_lng': -89.3272161, 'weight': 0.0012446767091965987}
# {'address': 'Calzada Revolución del 71 Zona 1, San Marcos, San Marcos', 'min_dist': 0.0010702765490448317, 'name': {'Delegación San Marcos'}, 'web_lat': 14.6450555, 'web_lng': -90.57509750000001, 'weight': 7.801456462849112e-06}
# {'address': '3 Calle Zona 2, Concepción Chiquirichapa, Quetzaltenango', 'min_dist': 0.003236883374051178, 'name': {'Delegación Concepción Chiquirichapa'}, 'web_lat': 14.8403808, 'web_lng': -91.52162349999999, 'weight': 0.00029072442680530444}
# {'address': 'Kilometro 164.5 Carretera a Cobán, Purulha, Baja Verapaz', 'min_dist': 0.003802163908503947, 'name': {'Delegación Purulha'}, 'web_lat': 15.2354488, 'web_lng': -90.2350201, 'weight': 0.013138551470408655}
# {'address': 'Barrio San Pedro Calle Principal frente al Puente Fray Bartolomé, Sacapulas, Quiché', 'min_dist': 0.005462077182415406, 'name': {'Delegación Sacapulas'}, 'web_lat': 15.2855993, 'web_lng': -91.0909492, 'weight': 0.011496232536607573}
# {'address': 'Aldea San Antonio, Serchil, San Marcos', 'min_dist': 0.005532401884483076, 'name': {'Delegación Serchil'}, 'web_lat': 15.0413661, 'web_lng': -91.80928139999999, 'weight': 0.008360896390260053}
# {'address': '0 Avenida 5 Calle Zona 2 Barrio el Rosario, Coatepeque, Quetzaltenango', 'min_dist': 0.005842317326933653, 'name': {'Delegación Coatepeque'}, 'web_lat': 14.7027395, 'web_lng': -91.8673479, 'weight': 0.01081998356386595}
# {'address': 'Casa #2 Colonia San Josecito Zona 1, Retalhuleu, Retalhuleu', 'min_dist': 0.007412757905776585, 'name': {'Delegación Retalhuleu'}, 'web_lat': 14.5414893, 'web_lng': -91.67628169999999, 'weight': 0.003470135467605454}
# {'address': '4 Avenida 3-71 Zona 2, Tejutla, San Marcos', 'min_dist': 0.00809367862682676, 'name': {'Delegación Tejutla'}, 'web_lat': 15.1275014, 'web_lng': -91.80502179999999, 'weight': 0.01081998356386595}
# {'address': '1 Avenida 3-51 Zona 1, Mazatenango, Suchitepequez', 'min_dist': 0.00971654116521735, 'name': {'Delegación Mazatenango'}, 'web_lat': 14.5364097, 'web_lng': -91.5058097, 'weight': 0.009196986029286059}
# {'address': '6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa', 'min_dist': 0.025734672871795507, 'name': {'Comité Internacional de la Cruz Roja'}, 'web_lat': 14.6396707, 'web_lng': -90.5142742, 'weight': 0.034482758620689655}
# {'address': '1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos', 'min_dist': 0.06978178822062167, 'name': {'Bolsa de Trabajo'}, 'web_lat': 14.68003, 'web_lng': -92.132172, 'weight': 0.041666666666666664}
# {'address': '8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala', 'min_dist': 0.07445065156764877, 'name': {'Sede Central'}, 'web_lat': 14.6506904, 'web_lng': -90.51013080000001, 'weight': 0.043478260869565216}
# {'address': '3 Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala', 'min_dist': 0.09288494204043589, 'name': {'Delegación Guatemala'}, 'web_lat': 14.6504251, 'web_lng': -90.5134787, 'weight': 0.0035614548220161235}
# {'address': '6 Avenida 6 Calle "B" 6-36 Zona 1, El Palmar, Quetzaltenango', 'min_dist': 0.15474155273811316, 'name': {'Delegación El Palmar'}, 'web_lat': 14.6463245, 'web_lng': -91.5559775, 'weight': 0.001382974121329554}
# {'address': '9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula', 'min_dist': 0.3695398746244929, 'name': {'Delegación Chiquimula'}, 'web_lat': 14.8023174, 'web_lng': -89.54185199999999, 'weight': 0.0035614548220161235}
# {'address': '1 Avenida 3-51 Zona 1, Quetzaltenango, Quetzaltenango', 'min_dist': 0.39352972259868263, 'name': {'Delegación Quetzaltenango'}, 'web_lat': 14.86795, 'web_lng': -91.5656556, 'weight': 0.0030074507385913934}
# {'address': '13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché', 'min_dist': 0.5227354551373742, 'name': {'Teléfonos 24/7'}, 'web_lat': 15.0248589, 'web_lng': -91.14727099999999, 'weight': 0.09090909090909091}
# {'address': '3 Avenida Zona 1 Barrio El Porvenir, San Benito, Petén', 'min_dist': 0.6422083505888369, 'name': {'Delegación Petén'}, 'web_lat': 16.9192846, 'web_lng': -89.90637579999999, 'weight': 0.015328310048810096}

# %%
pd.DataFrame(matched_list)
# Out:
#                                                                                  address  \
# 0                           3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.
# 1                                               3 Calle 2-13 Zona 3, Cobán, Alta Verapaz
# 2   Colonia Colina I 1 Calle atrás del Mercado Cantonal, Santo Tomás de Castilla, Izabal
# 3                                             9 Calle 5 Avenida Zona 1, El Estor, Izabal
# 4                               Calzada Revolución del 71 Zona 1, San Marcos, San Marcos
# 5                               3 Calle Zona 2, Concepción Chiquirichapa, Quetzaltenango
# 6                               Kilometro 164.5 Carretera a Cobán, Purulha, Baja Verapaz
# 7    Barrio San Pedro Calle Principal frente al Puente Fray Bartolomé, Sacapulas, Quiché
# 8                                                 Aldea San Antonio, Serchil, San Marcos
# 9                 0 Avenida 5 Calle Zona 2 Barrio el Rosario, Coatepeque, Quetzaltenango
# 10                           Casa #2 Colonia San Josecito Zona 1, Retalhuleu, Retalhuleu
# 11                                            4 Avenida 3-71 Zona 2, Tejutla, San Marcos
# 12                                     1 Avenida 3-51 Zona 1, Mazatenango, Suchitepequez
# 13                            6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa
# 14                                         1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos
# 15                                 8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala
# 16                                   3 Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala
# 17                          6 Avenida 6 Calle "B" 6-36 Zona 1, El Palmar, Quetzaltenango
# 18         9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula
# 19                                 1 Avenida 3-51 Zona 1, Quetzaltenango, Quetzaltenango
# 20                     13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché
# 21                                3 Avenida Zona 1 Barrio El Porvenir, San Benito, Petén
#
#     min_dist  \
# 0   0.000000
# 1   0.000000
# 2   0.000002
# 3   0.000972
# 4   0.001070
# 5   0.003237
# 6   0.003802
# 7   0.005462
# 8   0.005532
# 9   0.005842
# 10  0.007413
# 11  0.008094
# 12  0.009717
# 13  0.025735
# 14  0.069782
# 15  0.074451
# 16  0.092885
# 17  0.154742
# 18  0.369540
# 19  0.393530
# 20  0.522735
# 21  0.642208
#
#                                                                                        name  \
# 0   {Copyright © 2015 - Cruz Roja Guatemalteca, Contactenos | Cruz Roja Guatemalteca, Roja}
# 1                                                                                   {#Cruz}
# 2                                                      {Delegación Santo Tomás de Castilla}
# 3                                                                     {Delegación El Estor}
# 4                                                                   {Delegación San Marcos}
# 5                                                     {Delegación Concepción Chiquirichapa}
# 6                                                                      {Delegación Purulha}
# 7                                                                    {Delegación Sacapulas}
# 8                                                                      {Delegación Serchil}
# 9                                                                   {Delegación Coatepeque}
# 10                                                                  {Delegación Retalhuleu}
# 11                                                                     {Delegación Tejutla}
# 12                                                                 {Delegación Mazatenango}
# 13                                                   {Comité Internacional de la Cruz Roja}
# 14                                                                       {Bolsa de Trabajo}
# 15                                                                           {Sede Central}
# 16                                                                   {Delegación Guatemala}
# 17                                                                   {Delegación El Palmar}
# 18                                                                  {Delegación Chiquimula}
# 19                                                              {Delegación Quetzaltenango}
# 20                                                                         {Teléfonos 24/7}
# 21                                                                       {Delegación Petén}
#
#       web_lat    web_lng    weight
# 0   14.645276 -90.510688  0.030303
# 1   15.469403 -90.371813  0.071429
# 2   15.685270 -88.616592  0.000002
# 3   15.524558 -89.327216  0.001245
# 4   14.645055 -90.575098  0.000008
# 5   14.840381 -91.521623  0.000291
# 6   15.235449 -90.235020  0.013139
# 7   15.285599 -91.090949  0.011496
# 8   15.041366 -91.809281  0.008361
# 9   14.702739 -91.867348  0.010820
# 10  14.541489 -91.676282  0.003470
# 11  15.127501 -91.805022  0.010820
# 12  14.536410 -91.505810  0.009197
# 13  14.639671 -90.514274  0.034483
# 14  14.680030 -92.132172  0.041667
# 15  14.650690 -90.510131  0.043478
# 16  14.650425 -90.513479  0.003561
# 17  14.646325 -91.555977  0.001383
# 18  14.802317 -89.541852  0.003561
# 19  14.867950 -91.565656  0.003007
# 20  15.024859 -91.147271  0.090909
# 21  16.919285 -89.906376  0.015328

# %%
pd.set_option('display.max_colwidth',100)

# %%
min_dist_df_gt.sort_values(['name','min_dist'],ascending=True).groupby('name').head(1)
# Out:
#                                                                                   address  \
# 336                                              3 Calle 2-13 Zona 3, Cobán, Alta Verapaz
# 457                            6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa
# 81                                          1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos
# 442                            6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa
# 662                          3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.
# 669                          3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.
# 694         9 Calle "A" atrás de Gobernación Departamental Zona 1, Chiquimula, Chiquimula
# 144                0 Avenida 5 Calle Zona 2 Barrio el Rosario, Coatepeque, Quetzaltenango
# 352                                              3 Calle 2-13 Zona 3, Cobán, Alta Verapaz
# 608                              3 Calle Zona 2, Concepción Chiquirichapa, Quetzaltenango
# 184                                            9 Calle 5 Avenida Zona 1, El Estor, Izabal
# 201                          6 Avenida 6 Calle "B" 6-36 Zona 1, El Palmar, Quetzaltenango
# 413                                   3 Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala
# 434                            6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa
# 480                                     1 Avenida 3-51 Zona 1, Mazatenango, Suchitepequez
# 527                                3 Avenida Zona 1 Barrio El Porvenir, San Benito, Petén
# 324                              Kilometro 164.5 Carretera a Cobán, Purulha, Baja Verapaz
# 615                              3 Calle Zona 2, Concepción Chiquirichapa, Quetzaltenango
# 24                      13 Calle 1-66 Zona 5 Frente a CDAG, Santa Cruz del Quiché, Quiché
# 115                           Casa #2 Colonia San Josecito Zona 1, Retalhuleu, Retalhuleu
# 271   Barrio San Pedro Calle Principal frente al Puente Fray Bartolomé, Sacapulas, Quiché
# 231                              Calzada Revolución del 71 Zona 1, San Marcos, San Marcos
# 656  Colonia Colina I 1 Calle atrás del Mercado Cantonal, Santo Tomás de Castilla, Izabal
# 383                                                Aldea San Antonio, Serchil, San Marcos
# 74                                          1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos
# 572                                            4 Avenida 3-71 Zona 2, Tejutla, San Marcos
# 64                                  8 Avenida 3-31 Zona 1, Ciudad de Guatemala, Guatemala
# 355                                              3 Calle 2-13 Zona 3, Cobán, Alta Verapaz
# 307                              Kilometro 164.5 Carretera a Cobán, Purulha, Baja Verapaz
# 353                                              3 Calle 2-13 Zona 3, Cobán, Alta Verapaz
# 690                          3ra. Calle 8-40 Zona 1, Ciudad de Guatemala, Guatemala, C.A.
# 433                            6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa
# 92                                          1 Avenida 4-38 Zona 1, Tecún Umán, San Marcos
#
#      min_dist                                       name    web_lat  \
# 336  0.000000                                      #Cruz  15.469403
# 457  6.589822                    Acceso a la Información  14.639671
# 81   0.069782                           Bolsa de Trabajo  14.680030
# 442  0.025735       Comité Internacional de la Cruz Roja  14.639671
# 662  0.000000       Contactenos | Cruz Roja Guatemalteca  14.645276
# 669  0.000000  Copyright © 2015 - Cruz Roja Guatemalteca  14.645276
# 694  0.369540                      Delegación Chiquimula  14.802317
# 144  0.005842                      Delegación Coatepeque  14.702739
# 352  0.007595                           Delegación Cobán  15.469403
# 608  0.003237        Delegación Concepción Chiquirichapa  14.840381
# 184  0.000972                        Delegación El Estor  15.524558
# 201  0.154742                       Delegación El Palmar  14.646325
# 413  0.092885                       Delegación Guatemala  14.650425
# 434  0.230324                          Delegación Jalapa  14.639671
# 480  0.009717                     Delegación Mazatenango  14.536410
# 527  0.642208                           Delegación Petén  16.919285
# 324  0.003802                         Delegación Purulha  15.235449
# 615  0.143650                  Delegación Quetzaltenango  14.840381
# 24   0.594124                          Delegación Quiché  15.024859
# 115  0.007413                      Delegación Retalhuleu  14.541489
# 271  0.005462                       Delegación Sacapulas  15.285599
# 231  0.001070                      Delegación San Marcos  14.645055
# 656  0.000002         Delegación Santo Tomás de Castilla  15.685270
# 383  0.005532                         Delegación Serchil  15.041366
# 74   0.080350                      Delegación Tecún Umán  14.680030
# 572  0.008094                         Delegación Tejutla  15.127501
# 64   5.036196   Federación Internacional de la Cruz Roja  14.650690
# 355  0.042524                                   Juventud  15.469403
# 307  1.495723                            Nombre Completo  15.235449
# 353  6.316989                                       País  15.469403
# 690  0.000000                                       Roja  14.645276
# 433  0.046959                               Sede Central  14.639671
# 92   0.173681                             Teléfonos 24/7  14.680030
#
#        web_lng    weight
# 336 -90.371813  0.071429
# 457 -90.514274  0.038462
# 81  -92.132172  0.041667
# 442 -90.514274  0.034483
# 662 -90.510688  0.029412
# 669 -90.510688  0.030303
# 694 -89.541852  0.003561
# 144 -91.867348  0.010820
# 352 -90.371813  0.011148
# 608 -91.521623  0.000291
# 184 -89.327216  0.001245
# 201 -91.555977  0.001383
# 413 -90.513479  0.003561
# 434 -90.514274  0.004101
# 480 -91.505810  0.009197
# 527 -89.906376  0.015328
# 324 -90.235020  0.013139
# 615 -91.521623  0.006689
# 24  -91.147271  0.005413
# 115 -91.676282  0.003470
# 271 -91.090949  0.011496
# 231 -90.575098  0.000008
# 656 -88.616592  0.000002
# 383 -91.809281  0.008361
# 74  -92.132172  0.000458
# 572 -91.805022  0.010820
# 64  -90.510131  0.028571
# 355 -90.371813  0.076923
# 307 -90.235020  0.038462
# 353 -90.371813  0.166667
# 690 -90.510688  0.250000
# 433 -90.514274  0.055556
# 92  -92.132172  0.055556

# %%
[i[0] for i in addresses_list_gt]

# %% [markdown]
# use dictionary based approach to remove useless candidate

# %%
from elasticsearch import Elasticsearch

# %%
es=Elasticsearch()
filtered_candidate_gt=[]
for candidate in name_candidate_gt:
    try:
        result=es.search(index='gt',body={
              "query": {
               "query_string": {
              "query": candidate,
              "fields": [
              "FULL_NAME_RO"
              ]}}})
        if len(result)>0:
            condidates=[condidate['_source']['FULL_NAME_RO']for condidate in result['hits']['hits']]
            print(candidate)
            print(condidates)
            if len(condidates) >0:
                filtered_candidate_gt.append(candidate)
    except:
        pass
# Out:
# Conocer las Delegaciones
# ['Las Cuevas', 'Las Delicias', 'Las Minas', 'Las Mesitas', 'Las Tablas', 'Las Amelias', 'Las Ilusiones', 'Las Chachas', 'Las Casonas', 'Las Palmas']
# Teléfono: 7872-0182
# []
# Acceso a la Información
# ['La Monta帽a', 'La Vij铆a', 'La Tejer铆a', 'La Sure帽a', 'La Monta帽a', 'La Tuber铆a', 'La Monta帽a', 'La Monta帽a', 'La Tener铆a', 'La Tejer铆a']
# Blog
# []
# Galería
# []
# Juventud
# ['Juventud', 'Juventud', 'Juventud', 'Juventud', 'La Juventud', 'La Juventud', 'La Juventud', 'La Juventud']
# Delegación El Palmar
# ['El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar', 'El Palmar']
# #Cruz
# ['Cruz', 'Cruz', 'Santa Cruz', 'Cruz Chema', 'Cruz Creek', 'Santa Cruz', 'La Cruz', 'Cruz Blanca', 'Santa Cruz', 'La Cruz']
# Sede Central
# ['Central', 'Central', 'Central', 'Central', 'Central Xajaxac', 'La Central', 'Central Edwards', 'Central Progreso', 'Central Edwards', 'Central Progreso']
# Conocer más
# []
# Teléfono: 4772-5267
# []
# Delegaciones
# []
# Bolsa de Trabajo
# ['La Bolsa', 'La Bolsa', 'La Bolsa', 'La Bolsa', 'Finca La Bolsa', 'Finca La Bolsa', 'Finca La Bolsa', 'Finca La Bolsa', 'Finca La Bolsa', 'Finca La Bolsa']
# Botones Laterales
# []
# Teléfono: 4500-7121
# []
# País
# []
# Teléfono: 5859-7774
# []
# Delegación Petén
# []
# Teléfono: 7776-8402
# []
# Noticias
# []
# Salud
# []
# Delegación Chiquimula
# ['Chiquimula', 'Chiquimula', 'Chiquimula', 'Chiquimula', 'Chiquimula', 'Chiquimula', 'Municipio de Chiquimula', 'Departamento de Chiquimula', 'Municipio de Chiquimula', 'Departamento de Chiquimula']
# | NULL
# []
# Voluntariado
# []
# Delegación El Estor
# ['El Estor', 'El Estor', 'El Estor', 'El Estor', 'Municipio de El Estor', 'Municipio de El Estor', 'El Chol', 'El Mirador', 'El Brasilar', 'El Tanteal']
# y de la Media Luna Roja
# ['Media Luna', 'Media Luna', 'Media Luna', 'Media Luna', 'Pampa Media Luna', 'Finca Media Luna', 'Finca Media Luna', 'Pampa Media Luna', 'El Sol y La Luna', 'El Sol y La Luna']
# Teléfono: 2381-6531
# []
# YouTube
# []
# Delegación Quetzaltenango
# ['Quetzaltenango', 'Quetzaltenango', 'Quetzaltenango', 'Quetzaltenango', 'Quetzaltenango', 'Quetzaltenango', 'Municipio de Quetzaltenango', 'Departamento de Quetzaltenango', 'Municipio de Quetzaltenango', 'Departamento de Quetzaltenango']
# Delegación Sacapulas
# ['Sacapulas', 'Sacapulas', 'Sacapulas', 'Sacapulas', 'Sierra de Sacapulas', 'Municipio de Sacapulas', 'Municipio de Sacapulas', 'Sierra de Sacapulas']
# Semana Mayor
# ['Finca Santa Luc铆a Mayor', 'Finca Santa Luc铆a Mayor']
# Teléfono: 7761-2746
# []
# Teléfono: 3108-3672
# []
# <img src="images/img0.jpg">
# []
# Ver Boletines
# ['La Ver贸nica', 'La Ver贸nica', 'Laguneta La Ver贸nica', 'Laguneta La Ver贸nica']
# Vine
# []
# Desarrollo Organizativo
# ['Zona de Desarrollo Agrario Arizona', 'Zona de Desarrollo Agrario Arizona', 'Zona de Desarrollo Agrario Monterrey', 'Zona de Desarrollo Agrario Monterrey', 'Zona de Desarrollo Agrario El Chaperno', 'Zona de Desarrollo Agrario El Chaperno', 'Zona de Desarrollo Agrario Llano Grande', 'Zona de Desarrollo Agrario Santa Isabel', 'Zona de Desarrollo Agrario La Independencia', 'Zona de Desarrollo Agrario El Arisco']
# Delegación Quiché
# []
# Teléfono: 7760-0525
# []
# Boletines
# []
# Email
# []
# Dirección
# []
# Delegación San Marcos
# ['San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos', 'San Marcos']
# Teléfono: 7768-5360
# []
# Mensaje
# []
# Delegación Guatemala
# ['Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala', 'Guatemala']
# Teléfono: 5461-9661
# []
# Pinterest
# []
# Teléfono: 7775-1125
# []
# Instagram
# []
# Capacitaciones
# []
# Delegación Cobán
# []
# All in One SEO Pack
# ['Monument Number One Hundred and Seven', 'Monument Number One Hundred and Seven', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s', 'Santa In茅s']
# Delegación Purulha
# ['Municipio de San Antonio Purulha', 'Municipio de San Antonio Purulha']
# Delegación Tejutla
# ['Tejutla', 'Tejutla', 'Tejutla', 'Tejutla', 'Municipio de Tejutla', 'Municipio de Tejutla']
# LinkedIn
# []
# Biblioteca
# []
# Ciudad
# ['Ciudad Quetzal', 'Ciudad Vieja', 'Ciudad Vieja', 'Ciudad Real', 'Ciudad Universitaria', 'Ciudad Vieja', 'Ciudad Vieja', 'Ciudad Quetzal', 'Ciudad Real', 'Ciudad Universitaria']
# Teléfono: 7922-5226
# []
# Nosotros
# ['Hacienda San Jos茅 de Nosotros', 'Hacienda San Jos茅 de Nosotros']
# Contáctanos
# []
# Acciones
# []
# Delegación Mazatenango
# ['Mazatenango', 'Mazatenango', 'Mazatenango', 'Mazatenango', 'Municipio de Mazatenango', 'Municipio de Mazatenango']
# Teléfono
# []
# Roja
# ['La Cruz Roja', 'La Cruz Roja', 'Pe帽a Roja', 'Pe帽a Roja', 'Riachuelo Pe帽a Roja', 'Riachuelo Pe帽a Roja', 'Nueva Pe帽a Roja', 'Nueva Pe帽a Roja']
# WebMail
# []
# Donativos
# []
# Linea de Emergencias: 125
# ['De Lunas', 'De Lunas', 'Municipio de Melchor de Mencos', 'Municipio de Melchor de Mencos', 'Puerto de Matias de Galvez', 'Puerto de Matias de Cordoba', 'Puerto de Matias de Galvez', 'Puerto de Matias de Cordoba', 'Municipio de Santa Rosa de Lima', 'Riachuelo Ojo de Agua de Chuchuapa']
# Delegación Coatepeque
# ['Coatepeque', 'Coatepeque', 'Coatepeque', 'Coatepeque', 'Coatepeque', 'Coatepeque', 'Grupo Coatepeque', 'Grupo Coatepeque', 'Virgen Coatepeque', 'Virgen Coatepeque']
# None
# []
# Eventos
# []
# Teléfono: 7772-4205
# []
# Delegación Retalhuleu
# ['Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'Retalhuleu', 'San Felipe Retalhuleu', 'Municipio de Retalhuleu']
# #CruzRojaGT te recomienda
# ['Islote No Te Metas', 'Islote No Te Metas']
# Twitter
# []
# Delegación Jalapa
# ['Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa', 'Jalapa']
# Teléfono: 7771-5640
# []
# Teléfono: 7952-1459
# []
# Teléfono: 7942-2303
# []
# Nombre Completo
# ['Dulce Nombre', 'Dulce Nombre', 'Finca Dulce Nombre', 'El Dulce Nombre', 'Finca Dulce Nombre', 'Labor Dulce Nombre', 'Labor Dulce Nombre', 'El Dulce Nombre', 'Finca Dulce Nombre', 'Finca Dulce Nombre']
# Teléfono: 7949-7691
# []
# Facebook
# []
# Teléfono: 7755-6776
# []
# afb Instant Articles
# []
# Delegación Serchil
# ['Serchil', 'Serchil', 'Serchil', 'Serchil', 'Arroyo Serchil', 'Cerro Serchil', 'Cerro Serchil', 'Cerro Serchil', 'Arroyo Serchil', 'Cerro Serchil']
# Horario de Atención
# ['De Lunas', 'De Lunas', 'Municipio de Melchor de Mencos', 'Municipio de Melchor de Mencos', 'Puerto de Matias de Galvez', 'Puerto de Matias de Cordoba', 'Puerto de Matias de Galvez', 'Puerto de Matias de Cordoba', 'Municipio de Santa Rosa de Lima', 'Riachuelo Ojo de Agua de Chuchuapa']
# Alerta Amarilla
# []
# Delegación Tecún Umán
# []
# Tumblr
# []

# %% [markdown]
# failed to cover all targets

# %%
filtered_candidate_gt
# Out:
# ['Conocer las Delegaciones',
#  'Acceso a la Información',
#  'Juventud',
#  'Delegación El Palmar',
#  '#Cruz',
#  'Sede Central',
#  'Bolsa de Trabajo',
#  'Delegación Chiquimula',
#  'Delegación El Estor',
#  'y de la Media Luna Roja',
#  'Delegación Quetzaltenango',
#  'Delegación Sacapulas',
#  'Semana Mayor',
#  'Ver Boletines',
#  'Desarrollo Organizativo',
#  'Delegación San Marcos',
#  'Delegación Guatemala',
#  'All in One SEO Pack',
#  'Delegación Purulha',
#  'Delegación Tejutla',
#  'Ciudad',
#  'Nosotros',
#  'Delegación Mazatenango',
#  'Roja',
#  'Linea de Emergencias: 125',
#  'Delegación Coatepeque',
#  'Delegación Retalhuleu',
#  '#CruzRojaGT te recomienda',
#  'Delegación Jalapa',
#  'Nombre Completo',
#  'Delegación Serchil',
#  'Horario de Atención']

# %% [markdown]
# Compare to the TRUE dataset for NL case to do a simple evaluation

# %%
import requests
import lxml
from lxml import etree as et

# %%
text=requests.get("https://www.rodekruis.nl/wp-content/plugins/superstorefinder-wp/ssf-wp-xml.php")

# %%
address_et=et.fromstring (text.text)

# %%
address_et.find("locator")

# %%
address_et.tag
# Out:
# 'locator'

# %%
address_et
# Out:
# <Element locator at 0x1b5041a7508>

# %%
address_list_nl=[]
for child in address_et[5]:
    address_list_nl.append(child[1].text)

# %%
address_list_nl=list(set(address_list_nl))

# %%
len(address_list_nl)
# Out:
# 205

# %% [markdown]
# Only three out of 205 items are not covered

# %%
count=0
for address in address_list_nl:
    address=' '.join(address.split())
    if sum([1 for i in after_filter_nl if address in i]):
        count+=1
    else:
        print(address)
# Out:
# &#39;s Gravenlust 35 IJmuiden, Noord-Holland 1981 AE
# Vincent van Goghstraat 4 Zevenaar, Gelderland 6901 DK
# Karmel 255 BERGEN OP ZOOM, Noord-Brabant 4613 BS

# %%
count
# Out:
# 202

# %% [markdown]
# Save to files

# %%
nl_se=pd.Series(after_filter_nl)

# %%
nl_se.to_csv("../data/nl_se.csv")
# Out:
# D:\Applications\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
gt_se=pd.Series(after_filter_gt)

# %%
gt_se.to_csv("../data/gt_se.csv")
# Out:
# D:\Applications\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
QI2qcmn0
