# %%
import pandas as pd
import googlemaps

# %% [markdown]
# Build up connection to Google map service

# %%
client=googlemaps.Client("AIzaSyBnB3duxMNxArGL7wu9nWp9aOtV7lKx1Ao")

# %%
test=client.geocode("6 Avenida 1-99 Zona 1 Barrio La Democracia, Jalapa, Jalapa",region='gt')

# %%
test
# Out:
# [{'address_components': [{'long_name': '199',
#     'short_name': '199',
#     'types': ['street_number']},
#    {'long_name': '6A Avenida', 'short_name': '6A Avenida', 'types': ['route']},
#    {'long_name': 'Zona 1',
#     'short_name': 'Zona 1',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Guatemala',
#     'short_name': 'Guate',
#     'types': ['locality', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'Guatemala',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Guatemala',
#     'short_name': 'GT',
#     'types': ['country', 'political']}],
#   'formatted_address': '6A Avenida 199, Guatemala',
#   'geometry': {'location': {'lat': 14.6396707, 'lng': -90.5142742},
#    'location_type': 'RANGE_INTERPOLATED',
#    'viewport': {'northeast': {'lat': 14.6410196802915,
#      'lng': -90.5129252197085},
#     'southwest': {'lat': 14.6383217197085, 'lng': -90.51562318029151}}},
# ...

# %% [markdown]
# Extract Geo location information

# %%
def parse_response(return_json,query_name):
    return {
        "query_name":query_name,
        'formatted_address':return_json['formatted_address'],
        "lat":return_json['geometry']['location']['lat'],
        "lng":return_json['geometry']['location']['lng'],
    }

# %%
parse_response(test[0],"6 Avenida 1-99 Zona 1 Barrio La Democracia")
# Out:
# {'query_name': '6 Avenida 1-99 Zona 1 Barrio La Democracia',
#  'formatted_address': '8 Av 1-83 Z-1 Barrio la Democracia Jalapa Jalapa, 21001, Guatemala',
#  'lat': 14.6358286,
#  'lng': -89.98051679999999}

# %% [markdown]
# Query Geo location for Guatemala case

# %%
GT_se=pd.read_csv("gt_se.csv",header=None)

gt_list=GT_se[1]

# %%
result_list_gt_full_name=[]
for address in gt_list.to_list():
    result_query=client.geocode(address,region='gt')
    print(result_query)
    if len(result_query)<1:
        continue
    result_list_gt_full_name.append(parse_response(result_query[0],address))
# Out:
# [{'address_components': [{'long_name': '8', 'short_name': '8', 'types': ['street_number']}, {'long_name': '3 Calle', 'short_name': '3 Calle', 'types': ['route']}, {'long_name': 'Zona 2', 'short_name': 'Zona 2', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Guatemala', 'short_name': 'Guate', 'types': ['locality', 'political']}, {'long_name': 'Guatemala', 'short_name': 'Guatemala', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Guatemala', 'short_name': 'GT', 'types': ['country', 'political']}], 'formatted_address': '3 Calle 8, Guatemala', 'geometry': {'location': {'lat': 14.6504251, 'lng': -90.5134787}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 14.6517740802915, 'lng': -90.51212971970848}, 'southwest': {'lat': 14.6490761197085, 'lng': -90.51482768029149}}}, 'place_id': 'ChIJDd6k5Q6iiYUR-25xMyTk13M', 'plus_code': {'compound_code': 'MF2P+5J Guatemala City, Guatemala', 'global_code': '766FMF2P+5J'}, 'types': ['st
# ...

# %%
gt_result_full_name=pd.DataFrame(result_list_gt_full_name)

# %% [markdown]
# Save Geo location to file for Guatemala case

# %%
gt_result_full_name.to_csv("gt_result_full_name.csv")

# %% [markdown]
# Reformat csv file of social media data for Guatemala case

# %%
social_media=pd.read_csv("social_media_Guatemala.csv",delimiter="|")

# %%
social_media.to_csv("sm_gt.csv")

# %% [markdown]
# Query Geo location for Netherlands case

# %%
NL_se=pd.read_csv("nl_se.csv",header=None)

# %%
nl_list=NL_se[1]

# %%
result_list_nl_full_name=[]
for address in nl_list.to_list():
    result_query=client.geocode(address,region='nl')
    print(result_query)
    if len(result_query)<1:
        continue
    result_list_nl_full_name.append(parse_response(result_query[0],address))
# Out:
# [{'address_components': [{'long_name': '15A', 'short_name': '15A', 'types': ['street_number']}, {'long_name': 'Boerhaavestraat', 'short_name': 'Boerhaavestraat', 'types': ['route']}, {'long_name': 'Weert', 'short_name': 'Weert', 'types': ['locality', 'political']}, {'long_name': 'Weert', 'short_name': 'Weert', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Limburg', 'short_name': 'LI', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Netherlands', 'short_name': 'NL', 'types': ['country', 'political']}, {'long_name': '6001 AV', 'short_name': '6001 AV', 'types': ['postal_code']}], 'formatted_address': 'Boerhaavestraat 15A, 6001 AV Weert, Netherlands', 'geometry': {'location': {'lat': 51.25578669999999, 'lng': 5.7114425}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 51.25713568029149, 'lng': 5.712791480291502}, 'southwest': {'lat': 51.25443771970849, 'lng': 5.710093519708497}}}, 'place_id': 'ChIJfTKpOnkyx0cRvi5xvb-3ayc', 'pl
# ...

# %%
nl_result_full_name=pd.DataFrame(result_list_nl_full_name)

# %% [markdown]
# Save Geo location to file for Netherlands case

# %%
nl_result_full_name.to_csv("nl_result_full_name.csv")

# %% [markdown]
# Reformat csv file of social media data for Guatemala case

# %%
social_media_nl=pd.read_csv("social_media_Netherlands.csv",delimiter="|")

# %%
social_media_nl.to_csv("sm_nl.csv")

# %%
import requests
import lxml
from lxml import etree as et

# %% [markdown]
# Extract data from web API, parse XML to dataframe

# %%
text=requests.get("https://www.rodekruis.nl/wp-content/plugins/superstorefinder-wp/ssf-wp-xml.php")

# %%
address_et=et.fromstring (text.text)

# %%
address_et.find("locator")

# %%
address_list_nl=[]
for child in address_et[5]:
    #print(child[:])
    #print(child[3].text,child[4].text)
    address_list_nl.append({"name":child[0].text,"address":child[1].text,"lat":child[3].text,'lon':child[4].text})

# %%
pd.DataFrame(address_list_nl).to_csv('correct_nl.csv')

# %%
pd.DataFrame(address_list_nl)
# Out:
#                                                address         lat        lon  \
# 0        Postbus 440  Aalsmeer,  Noord-Holland 1430 AK  52.2666259  4.7510049
# 1    Gasthuisstraat 78  Winterswijk,  Gelderland 71...  51.9734384  6.7153642
# 2    Gasthuisstraat 78  Winterswijk,  Gelderland 71...  51.9734618  6.7153871
# 3    Gasthuisstraat 78  Winterswijk,  Gelderland 71...  51.9734618  6.7153871
# 4    Duivenstraat 70  Papendrecht,  Zuid-Holland 33...  51.8258030  4.6907499
# 5    Duivenstraat 70  Papendrecht,  Zuid-Holland 33...  51.8258030  4.6907499
# 6    Duivenstraat 70  Papendrecht,  Zuid-Holland 33...  51.8258030  4.6907499
# 7       Hofkampstraat 102  Almelo,  Overijssel 7607 NJ  52.3530579  6.6739634
# 8       Hofkampstraat 102  Almelo,  Overijssel 7607 NJ  52.3532884  6.6735415
# 9       Hofkampstraat 102  Almelo,  Overijssel 7607 NJ  52.3532884  6.6735415
# 10       Wagenmakerbaan 47  Almere,  Flevoland 1315 BC  52.3694673  5.2145011
# ...
